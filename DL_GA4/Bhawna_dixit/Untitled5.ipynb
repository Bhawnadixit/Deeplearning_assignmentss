# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt                           # plotting
import sklearn as sk
from IPython.display import Audio
from intervaltree import Interval,IntervalTree

print(tf.__version__)

# fix random seed for reproducibility
seed = 2020
np.random.seed(seed)



# %matplotlib inline
# Out:
# 2.4.1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4996ee3d8d09> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
 from google.colab import files
 ! pip install -q kaggle

# %%
 files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
#      <input type="file" id="files-ce7c966f-f016-4de1-9b10-123edc9a762d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce7c966f-f016-4de1-9b10-123edc9a762d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              223KB  2021-04-17 19:10:49           3095
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-02-17 16:10:44           1820
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           1235
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52            350
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            615
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            162
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            267
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39             66
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            392
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54             92
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            419
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51             55
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            173
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26             32
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40             43
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54             43
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         136056
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         133590
# rtatman/188-million-us-wildfires                            1.88 Million US Wildfires                         168MB  2020-05-12 21:03:49          14745
# datasnaek/chess                                             Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          16770

# %%
# !kaggle datasets list -s musicnet
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                 title                size  lastUpdated          downloadCount
# ----------------------------------  -------------------  ----  -------------------  -------------
# imsparsh/musicnet-dataset           MusicNet Dataset     22GB  2021-02-18 14:12:19            615
# rohitsingh0210/musicnet-midi-files  MusicNet midi files   3MB  2021-04-05 10:26:56              1

# %%
# !kaggle datasets download -d imsparsh/musicnet-dataset
# Out:
# Downloading musicnet-dataset.zip to /content
# 100% 21.5G/21.5G [06:05<00:00, 41.4MB/s]
# 100% 21.5G/21.5G [06:05<00:00, 63.1MB/s]

# %%
# !unzip musicnet-dataset.zip
# Out:
# Archive:  musicnet-dataset.zip
#   inflating: musicnet.npz
#   inflating: musicnet/musicnet/test_data/1759.wav
#   inflating: musicnet/musicnet/test_data/1819.wav
#   inflating: musicnet/musicnet/test_data/2106.wav
#   inflating: musicnet/musicnet/test_data/2191.wav
#   inflating: musicnet/musicnet/test_data/2298.wav
#   inflating: musicnet/musicnet/test_data/2303.wav
#   inflating: musicnet/musicnet/test_data/2382.wav
#   inflating: musicnet/musicnet/test_data/2416.wav
#   inflating: musicnet/musicnet/test_data/2556.wav
#   inflating: musicnet/musicnet/test_data/2628.wav
#   inflating: musicnet/musicnet/test_labels/1759.csv
#   inflating: musicnet/musicnet/test_labels/1819.csv
#   inflating: musicnet/musicnet/test_labels/2106.csv
#   inflating: musicnet/musicnet/test_labels/2191.csv
#   inflating: musicnet/musicnet/test_labels/2298.csv
#   inflating: musicnet/musicnet/test_labels/2303.csv
#   inflating: musicnet/musicnet/test_labels/2382.csv
#   inflating: musicnet/musicnet/test_labels/2416.csv
#   inflating: musicnet/musicnet/test_labels/2556.csv
#   inflating: musicnet/musicnet/test_labels/2628.csv
#   inflating: musicnet/musicnet/train_data/1727.wav
#   inflating: musicnet/musicnet/train_data/1728.wav
#   inflating: musicnet/musicnet/train_data/1729.wav
#   inflating: musicnet/musicnet/train_data/1730.wav
#   inflating: musicnet/musicnet/train_data/1733.wav
#   inflating: musicnet/musicnet/train_data/1734.wav
#   inflating: musicnet/musicnet/train_data/1735.wav
#   inflating: musicnet/musicnet/train_data/1739.wav
#   inflating: musicnet/musicnet/train_data/1742.wav
#   inflating: musicnet/musicnet/train_data/1749.wav
#   inflating: musicnet/musicnet/train_data/1750.wav
#   inflating: musicnet/musicnet/train_data/1751.wav
#   inflating: musicnet/musicnet/train_data/1752.wav
#   inflating: musicnet/musicnet/train_data/1755.wav
#   inflating: musicnet/musicnet/train_data/1756.wav
#   inflating: musicnet/musicnet/train_data/1757.wav
#   inflating: musicnet/musicnet/train_data/1758.wav
#   inflating: musicnet/musicnet/train_data/1760.wav
#   inflating: musicnet/musicnet/train_data/1763.wav
#   inflating: musicnet/musicnet/train_data/1764.wav
#   inflating: musicnet/musicnet/train_data/1765.wav
#   inflating: musicnet/musicnet/train_data/1766.wav
#   inflating: musicnet/musicnet/train_data/1768.wav
#   inflating: musicnet/musicnet/train_data/1771.wav
#   inflating: musicnet/musicnet/train_data/1772.wav
#   inflating: musicnet/musicnet/train_data/1773.wav
#   inflating: musicnet/musicnet/train_data/1775.wav
#   inflating: musicnet/musicnet/train_data/1776.wav
#   inflating: musicnet/musicnet/train_data/1777.wav
#   inflating: musicnet/musicnet/train_data/1788.wav
#   inflating: musicnet/musicnet/train_data/1789.wav
#   inflating: musicnet/musicnet/train_data/1790.wav
#   inflating: musicnet/musicnet/train_data/1791.wav
#   inflating: musicnet/musicnet/train_data/1792.wav
#   inflating: musicnet/musicnet/train_data/1793.wav
#   inflating: musicnet/musicnet/train_data/1805.wav
#   inflating: musicnet/musicnet/train_data/1807.wav
#   inflating: musicnet/musicnet/train_data/1811.wav
#   inflating: musicnet/musicnet/train_data/1812.wav
#   inflating: musicnet/musicnet/train_data/1813.wav
#   inflating: musicnet/musicnet/train_data/1817.wav
#   inflating: musicnet/musicnet/train_data/1818.wav
#   inflating: musicnet/musicnet/train_data/1822.wav
#   inflating: musicnet/musicnet/train_data/1824.wav
#   inflating: musicnet/musicnet/train_data/1828.wav
#   inflating: musicnet/musicnet/train_data/1829.wav
#   inflating: musicnet/musicnet/train_data/1835.wav
#   inflating: musicnet/musicnet/train_data/1859.wav
#   inflating: musicnet/musicnet/train_data/1872.wav
#   inflating: musicnet/musicnet/train_data/1873.wav
#   inflating: musicnet/musicnet/train_data/1876.wav
#   inflating: musicnet/musicnet/train_data/1893.wav
#   inflating: musicnet/musicnet/train_data/1916.wav
#   inflating: musicnet/musicnet/train_data/1918.wav
#   inflating: musicnet/musicnet/train_data/1919.wav
#   inflating: musicnet/musicnet/train_data/1922.wav
#   inflating: musicnet/musicnet/train_data/1923.wav
#   inflating: musicnet/musicnet/train_data/1931.wav
#   inflating: musicnet/musicnet/train_data/1932.wav
#   inflating: musicnet/musicnet/train_data/1933.wav
#   inflating: musicnet/musicnet/train_data/2075.wav
#   inflating: musicnet/musicnet/train_data/2076.wav
#   inflating: musicnet/musicnet/train_data/2077.wav
#   inflating: musicnet/musicnet/train_data/2078.wav
#   inflating: musicnet/musicnet/train_data/2079.wav
#   inflating: musicnet/musicnet/train_data/2080.wav
#   inflating: musicnet/musicnet/train_data/2081.wav
#   inflating: musicnet/musicnet/train_data/2082.wav
#   inflating: musicnet/musicnet/train_data/2083.wav
#   inflating: musicnet/musicnet/train_data/2104.wav
#   inflating: musicnet/musicnet/train_data/2105.wav
#   inflating: musicnet/musicnet/train_data/2112.wav
#   inflating: musicnet/musicnet/train_data/2113.wav
#   inflating: musicnet/musicnet/train_data/2114.wav
#   inflating: musicnet/musicnet/train_data/2116.wav
#   inflating: musicnet/musicnet/train_data/2117.wav
#   inflating: musicnet/musicnet/train_data/2118.wav
#   inflating: musicnet/musicnet/train_data/2119.wav
#   inflating: musicnet/musicnet/train_data/2127.wav
#   inflating: musicnet/musicnet/train_data/2131.wav
#   inflating: musicnet/musicnet/train_data/2138.wav
#   inflating: musicnet/musicnet/train_data/2140.wav
#   inflating: musicnet/musicnet/train_data/2147.wav
#   inflating: musicnet/musicnet/train_data/2148.wav
#   inflating: musicnet/musicnet/train_data/2149.wav
#   inflating: musicnet/musicnet/train_data/2150.wav
#   inflating: musicnet/musicnet/train_data/2151.wav
#   inflating: musicnet/musicnet/train_data/2154.wav
#   inflating: musicnet/musicnet/train_data/2155.wav
#   inflating: musicnet/musicnet/train_data/2156.wav
#   inflating: musicnet/musicnet/train_data/2157.wav
#   inflating: musicnet/musicnet/train_data/2158.wav
#   inflating: musicnet/musicnet/train_data/2159.wav
#   inflating: musicnet/musicnet/train_data/2160.wav
#   inflating: musicnet/musicnet/train_data/2161.wav
#   inflating: musicnet/musicnet/train_data/2166.wav
#   inflating: musicnet/musicnet/train_data/2167.wav
#   inflating: musicnet/musicnet/train_data/2168.wav
#   inflating: musicnet/musicnet/train_data/2169.wav
#   inflating: musicnet/musicnet/train_data/2177.wav
#   inflating: musicnet/musicnet/train_data/2178.wav
#   inflating: musicnet/musicnet/train_data/2179.wav
#   inflating: musicnet/musicnet/train_data/2180.wav
#   inflating: musicnet/musicnet/train_data/2186.wav
#   inflating: musicnet/musicnet/train_data/2194.wav
#   inflating: musicnet/musicnet/train_data/2195.wav
#   inflating: musicnet/musicnet/train_data/2196.wav
#   inflating: musicnet/musicnet/train_data/2198.wav
#   inflating: musicnet/musicnet/train_data/2200.wav
#   inflating: musicnet/musicnet/train_data/2201.wav
#   inflating: musicnet/musicnet/train_data/2202.wav
#   inflating: musicnet/musicnet/train_data/2203.wav
#   inflating: musicnet/musicnet/train_data/2204.wav
#   inflating: musicnet/musicnet/train_data/2207.wav
#   inflating: musicnet/musicnet/train_data/2208.wav
#   inflating: musicnet/musicnet/train_data/2209.wav
#   inflating: musicnet/musicnet/train_data/2210.wav
#   inflating: musicnet/musicnet/train_data/2211.wav
#   inflating: musicnet/musicnet/train_data/2212.wav
#   inflating: musicnet/musicnet/train_data/2213.wav
#   inflating: musicnet/musicnet/train_data/2214.wav
#   inflating: musicnet/musicnet/train_data/2215.wav
#   inflating: musicnet/musicnet/train_data/2217.wav
#   inflating: musicnet/musicnet/train_data/2218.wav
#   inflating: musicnet/musicnet/train_data/2219.wav
#   inflating: musicnet/musicnet/train_data/2220.wav
#   inflating: musicnet/musicnet/train_data/2221.wav
#   inflating: musicnet/musicnet/train_data/2222.wav
#   inflating: musicnet/musicnet/train_data/2224.wav
#   inflating: musicnet/musicnet/train_data/2225.wav
#   inflating: musicnet/musicnet/train_data/2227.wav
#   inflating: musicnet/musicnet/train_data/2228.wav
#   inflating: musicnet/musicnet/train_data/2229.wav
#   inflating: musicnet/musicnet/train_data/2230.wav
#   inflating: musicnet/musicnet/train_data/2231.wav
#   inflating: musicnet/musicnet/train_data/2232.wav
#   inflating: musicnet/musicnet/train_data/2234.wav
#   inflating: musicnet/musicnet/train_data/2237.wav
#   inflating: musicnet/musicnet/train_data/2238.wav
#   inflating: musicnet/musicnet/train_data/2239.wav
#   inflating: musicnet/musicnet/train_data/2240.wav
#   inflating: musicnet/musicnet/train_data/2241.wav
#   inflating: musicnet/musicnet/train_data/2242.wav
#   inflating: musicnet/musicnet/train_data/2243.wav
#   inflating: musicnet/musicnet/train_data/2244.wav
#   inflating: musicnet/musicnet/train_data/2247.wav
#   inflating: musicnet/musicnet/train_data/2248.wav
#   inflating: musicnet/musicnet/train_data/2282.wav
#   inflating: musicnet/musicnet/train_data/2283.wav
#   inflating: musicnet/musicnet/train_data/2284.wav
#   inflating: musicnet/musicnet/train_data/2285.wav
#   inflating: musicnet/musicnet/train_data/2288.wav
#   inflating: musicnet/musicnet/train_data/2289.wav
#   inflating: musicnet/musicnet/train_data/2292.wav
#   inflating: musicnet/musicnet/train_data/2293.wav
#   inflating: musicnet/musicnet/train_data/2294.wav
#   inflating: musicnet/musicnet/train_data/2295.wav
#   inflating: musicnet/musicnet/train_data/2296.wav
#   inflating: musicnet/musicnet/train_data/2297.wav
#   inflating: musicnet/musicnet/train_data/2300.wav
#   inflating: musicnet/musicnet/train_data/2302.wav
#   inflating: musicnet/musicnet/train_data/2304.wav
#   inflating: musicnet/musicnet/train_data/2305.wav
#   inflating: musicnet/musicnet/train_data/2307.wav
#   inflating: musicnet/musicnet/train_data/2308.wav
#   inflating: musicnet/musicnet/train_data/2310.wav
#   inflating: musicnet/musicnet/train_data/2313.wav
#   inflating: musicnet/musicnet/train_data/2314.wav
#   inflating: musicnet/musicnet/train_data/2315.wav
#   inflating: musicnet/musicnet/train_data/2318.wav
#   inflating: musicnet/musicnet/train_data/2319.wav
#   inflating: musicnet/musicnet/train_data/2320.wav
#   inflating: musicnet/musicnet/train_data/2322.wav
#   inflating: musicnet/musicnet/train_data/2325.wav
#   inflating: musicnet/musicnet/train_data/2330.wav
#   inflating: musicnet/musicnet/train_data/2334.wav
#   inflating: musicnet/musicnet/train_data/2335.wav
#   inflating: musicnet/musicnet/train_data/2336.wav
#   inflating: musicnet/musicnet/train_data/2341.wav
#   inflating: musicnet/musicnet/train_data/2342.wav
#   inflating: musicnet/musicnet/train_data/2343.wav
#   inflating: musicnet/musicnet/train_data/2345.wav
#   inflating: musicnet/musicnet/train_data/2346.wav
#   inflating: musicnet/musicnet/train_data/2348.wav
#   inflating: musicnet/musicnet/train_data/2350.wav
#   inflating: musicnet/musicnet/train_data/2357.wav
#   inflating: musicnet/musicnet/train_data/2358.wav
#   inflating: musicnet/musicnet/train_data/2359.wav
#   inflating: musicnet/musicnet/train_data/2364.wav
#   inflating: musicnet/musicnet/train_data/2365.wav
#   inflating: musicnet/musicnet/train_data/2366.wav
#   inflating: musicnet/musicnet/train_data/2368.wav
#   inflating: musicnet/musicnet/train_data/2371.wav
#   inflating: musicnet/musicnet/train_data/2372.wav
#   inflating: musicnet/musicnet/train_data/2373.wav
#   inflating: musicnet/musicnet/train_data/2374.wav
#   inflating: musicnet/musicnet/train_data/2376.wav
#   inflating: musicnet/musicnet/train_data/2377.wav
#   inflating: musicnet/musicnet/train_data/2379.wav
#   inflating: musicnet/musicnet/train_data/2381.wav
#   inflating: musicnet/musicnet/train_data/2383.wav
#   inflating: musicnet/musicnet/train_data/2384.wav
#   inflating: musicnet/musicnet/train_data/2388.wav
#   inflating: musicnet/musicnet/train_data/2389.wav
#   inflating: musicnet/musicnet/train_data/2390.wav
#   inflating: musicnet/musicnet/train_data/2391.wav
#   inflating: musicnet/musicnet/train_data/2392.wav
#   inflating: musicnet/musicnet/train_data/2393.wav
#   inflating: musicnet/musicnet/train_data/2397.wav
#   inflating: musicnet/musicnet/train_data/2398.wav
#   inflating: musicnet/musicnet/train_data/2403.wav
#   inflating: musicnet/musicnet/train_data/2404.wav
#   inflating: musicnet/musicnet/train_data/2405.wav
#   inflating: musicnet/musicnet/train_data/2406.wav
#   inflating: musicnet/musicnet/train_data/2410.wav
#   inflating: musicnet/musicnet/train_data/2411.wav
#   inflating: musicnet/musicnet/train_data/2415.wav
#   inflating: musicnet/musicnet/train_data/2417.wav
#   inflating: musicnet/musicnet/train_data/2420.wav
#   inflating: musicnet/musicnet/train_data/2422.wav
#   inflating: musicnet/musicnet/train_data/2423.wav
#   inflating: musicnet/musicnet/train_data/2424.wav
#   inflating: musicnet/musicnet/train_data/2431.wav
#   inflating: musicnet/musicnet/train_data/2432.wav
#   inflating: musicnet/musicnet/train_data/2433.wav
#   inflating: musicnet/musicnet/train_data/2436.wav
#   inflating: musicnet/musicnet/train_data/2441.wav
#   inflating: musicnet/musicnet/train_data/2442.wav
#   inflating: musicnet/musicnet/train_data/2443.wav
#   inflating: musicnet/musicnet/train_data/2444.wav
#   inflating: musicnet/musicnet/train_data/2451.wav
#   inflating: musicnet/musicnet/train_data/2462.wav
#   inflating: musicnet/musicnet/train_data/2463.wav
#   inflating: musicnet/musicnet/train_data/2466.wav
#   inflating: musicnet/musicnet/train_data/2471.wav
#   inflating: musicnet/musicnet/train_data/2472.wav
#   inflating: musicnet/musicnet/train_data/2473.wav
#   inflating: musicnet/musicnet/train_data/2476.wav
#   inflating: musicnet/musicnet/train_data/2477.wav
#   inflating: musicnet/musicnet/train_data/2478.wav
#   inflating: musicnet/musicnet/train_data/2480.wav
#   inflating: musicnet/musicnet/train_data/2481.wav
#   inflating: musicnet/musicnet/train_data/2482.wav
#   inflating: musicnet/musicnet/train_data/2483.wav
#   inflating: musicnet/musicnet/train_data/2486.wav
#   inflating: musicnet/musicnet/train_data/2487.wav
#   inflating: musicnet/musicnet/train_data/2488.wav
#   inflating: musicnet/musicnet/train_data/2490.wav
#   inflating: musicnet/musicnet/train_data/2491.wav
#   inflating: musicnet/musicnet/train_data/2492.wav
#   inflating: musicnet/musicnet/train_data/2494.wav
#   inflating: musicnet/musicnet/train_data/2497.wav
#   inflating: musicnet/musicnet/train_data/2501.wav
#   inflating: musicnet/musicnet/train_data/2502.wav
#   inflating: musicnet/musicnet/train_data/2504.wav
#   inflating: musicnet/musicnet/train_data/2505.wav
#   inflating: musicnet/musicnet/train_data/2506.wav
#   inflating: musicnet/musicnet/train_data/2507.wav
#   inflating: musicnet/musicnet/train_data/2509.wav
#   inflating: musicnet/musicnet/train_data/2510.wav
#   inflating: musicnet/musicnet/train_data/2512.wav
#   inflating: musicnet/musicnet/train_data/2514.wav
#   inflating: musicnet/musicnet/train_data/2516.wav
#   inflating: musicnet/musicnet/train_data/2521.wav
#   inflating: musicnet/musicnet/train_data/2522.wav
#   inflating: musicnet/musicnet/train_data/2523.wav
#   inflating: musicnet/musicnet/train_data/2527.wav
#   inflating: musicnet/musicnet/train_data/2528.wav
#   inflating: musicnet/musicnet/train_data/2529.wav
#   inflating: musicnet/musicnet/train_data/2530.wav
#   inflating: musicnet/musicnet/train_data/2531.wav
#   inflating: musicnet/musicnet/train_data/2532.wav
#   inflating: musicnet/musicnet/train_data/2533.wav
#   inflating: musicnet/musicnet/train_data/2537.wav
#   inflating: musicnet/musicnet/train_data/2538.wav
#   inflating: musicnet/musicnet/train_data/2540.wav
#   inflating: musicnet/musicnet/train_data/2542.wav
#   inflating: musicnet/musicnet/train_data/2550.wav
#   inflating: musicnet/musicnet/train_data/2555.wav
#   inflating: musicnet/musicnet/train_data/2557.wav
#   inflating: musicnet/musicnet/train_data/2560.wav
#   inflating: musicnet/musicnet/train_data/2562.wav
#   inflating: musicnet/musicnet/train_data/2564.wav
#   inflating: musicnet/musicnet/train_data/2566.wav
#   inflating: musicnet/musicnet/train_data/2567.wav
#   inflating: musicnet/musicnet/train_data/2568.wav
#   inflating: musicnet/musicnet/train_data/2570.wav
#   inflating: musicnet/musicnet/train_data/2571.wav
#   inflating: musicnet/musicnet/train_data/2572.wav
#   inflating: musicnet/musicnet/train_data/2573.wav
#   inflating: musicnet/musicnet/train_data/2575.wav
#   inflating: musicnet/musicnet/train_data/2576.wav
#   inflating: musicnet/musicnet/train_data/2581.wav
#   inflating: musicnet/musicnet/train_data/2582.wav
#   inflating: musicnet/musicnet/train_data/2586.wav
#   inflating: musicnet/musicnet/train_data/2588.wav
#   inflating: musicnet/musicnet/train_data/2590.wav
#   inflating: musicnet/musicnet/train_data/2591.wav
#   inflating: musicnet/musicnet/train_data/2593.wav
#   inflating: musicnet/musicnet/train_data/2594.wav
#   inflating: musicnet/musicnet/train_data/2595.wav
#   inflating: musicnet/musicnet/train_data/2596.wav
#   inflating: musicnet/musicnet/train_data/2603.wav
#   inflating: musicnet/musicnet/train_data/2607.wav
#   inflating: musicnet/musicnet/train_data/2608.wav
#   inflating: musicnet/musicnet/train_data/2611.wav
#   inflating: musicnet/musicnet/train_data/2614.wav
#   inflating: musicnet/musicnet/train_data/2618.wav
#   inflating: musicnet/musicnet/train_data/2619.wav
#   inflating: musicnet/musicnet/train_data/2620.wav
#   inflating: musicnet/musicnet/train_data/2621.wav
#   inflating: musicnet/musicnet/train_data/2622.wav
#   inflating: musicnet/musicnet/train_data/2626.wav
#   inflating: musicnet/musicnet/train_data/2627.wav
#   inflating: musicnet/musicnet/train_data/2629.wav
#   inflating: musicnet/musicnet/train_data/2632.wav
#   inflating: musicnet/musicnet/train_data/2633.wav
#   inflating: musicnet/musicnet/train_data/2659.wav
#   inflating: musicnet/musicnet/train_data/2677.wav
#   inflating: musicnet/musicnet/train_data/2678.wav
#   inflating: musicnet/musicnet/train_labels/1727.csv
#   inflating: musicnet/musicnet/train_labels/1728.csv
#   inflating: musicnet/musicnet/train_labels/1729.csv
#   inflating: musicnet/musicnet/train_labels/1730.csv
#   inflating: musicnet/musicnet/train_labels/1733.csv
#   inflating: musicnet/musicnet/train_labels/1734.csv
#   inflating: musicnet/musicnet/train_labels/1735.csv
#   inflating: musicnet/musicnet/train_labels/1739.csv
#   inflating: musicnet/musicnet/train_labels/1742.csv
#   inflating: musicnet/musicnet/train_labels/1749.csv
#   inflating: musicnet/musicnet/train_labels/1750.csv
#   inflating: musicnet/musicnet/train_labels/1751.csv
#   inflating: musicnet/musicnet/train_labels/1752.csv
#   inflating: musicnet/musicnet/train_labels/1755.csv
#   inflating: musicnet/musicnet/train_labels/1756.csv
#   inflating: musicnet/musicnet/train_labels/1757.csv
#   inflating: musicnet/musicnet/train_labels/1758.csv
#   inflating: musicnet/musicnet/train_labels/1760.csv
#   inflating: musicnet/musicnet/train_labels/1763.csv
#   inflating: musicnet/musicnet/train_labels/1764.csv
#   inflating: musicnet/musicnet/train_labels/1765.csv
#   inflating: musicnet/musicnet/train_labels/1766.csv
#   inflating: musicnet/musicnet/train_labels/1768.csv
#   inflating: musicnet/musicnet/train_labels/1771.csv
#   inflating: musicnet/musicnet/train_labels/1772.csv
#   inflating: musicnet/musicnet/train_labels/1773.csv
#   inflating: musicnet/musicnet/train_labels/1775.csv
#   inflating: musicnet/musicnet/train_labels/1776.csv
#   inflating: musicnet/musicnet/train_labels/1777.csv
#   inflating: musicnet/musicnet/train_labels/1788.csv
#   inflating: musicnet/musicnet/train_labels/1789.csv
#   inflating: musicnet/musicnet/train_labels/1790.csv
#   inflating: musicnet/musicnet/train_labels/1791.csv
#   inflating: musicnet/musicnet/train_labels/1792.csv
#   inflating: musicnet/musicnet/train_labels/1793.csv
#   inflating: musicnet/musicnet/train_labels/1805.csv
#   inflating: musicnet/musicnet/train_labels/1807.csv
#   inflating: musicnet/musicnet/train_labels/1811.csv
#   inflating: musicnet/musicnet/train_labels/1812.csv
#   inflating: musicnet/musicnet/train_labels/1813.csv
#   inflating: musicnet/musicnet/train_labels/1817.csv
#   inflating: musicnet/musicnet/train_labels/1818.csv
#   inflating: musicnet/musicnet/train_labels/1822.csv
#   inflating: musicnet/musicnet/train_labels/1824.csv
#   inflating: musicnet/musicnet/train_labels/1828.csv
#   inflating: musicnet/musicnet/train_labels/1829.csv
#   inflating: musicnet/musicnet/train_labels/1835.csv
#   inflating: musicnet/musicnet/train_labels/1859.csv
#   inflating: musicnet/musicnet/train_labels/1872.csv
#   inflating: musicnet/musicnet/train_labels/1873.csv
#   inflating: musicnet/musicnet/train_labels/1876.csv
#   inflating: musicnet/musicnet/train_labels/1893.csv
#   inflating: musicnet/musicnet/train_labels/1916.csv
#   inflating: musicnet/musicnet/train_labels/1918.csv
#   inflating: musicnet/musicnet/train_labels/1919.csv
#   inflating: musicnet/musicnet/train_labels/1922.csv
#   inflating: musicnet/musicnet/train_labels/1923.csv
#   inflating: musicnet/musicnet/train_labels/1931.csv
#   inflating: musicnet/musicnet/train_labels/1932.csv
#   inflating: musicnet/musicnet/train_labels/1933.csv
#   inflating: musicnet/musicnet/train_labels/2075.csv
#   inflating: musicnet/musicnet/train_labels/2076.csv
#   inflating: musicnet/musicnet/train_labels/2077.csv
#   inflating: musicnet/musicnet/train_labels/2078.csv
#   inflating: musicnet/musicnet/train_labels/2079.csv
#   inflating: musicnet/musicnet/train_labels/2080.csv
#   inflating: musicnet/musicnet/train_labels/2081.csv
#   inflating: musicnet/musicnet/train_labels/2082.csv
#   inflating: musicnet/musicnet/train_labels/2083.csv
#   inflating: musicnet/musicnet/train_labels/2104.csv
#   inflating: musicnet/musicnet/train_labels/2105.csv
#   inflating: musicnet/musicnet/train_labels/2112.csv
#   inflating: musicnet/musicnet/train_labels/2113.csv
#   inflating: musicnet/musicnet/train_labels/2114.csv
#   inflating: musicnet/musicnet/train_labels/2116.csv
#   inflating: musicnet/musicnet/train_labels/2117.csv
#   inflating: musicnet/musicnet/train_labels/2118.csv
#   inflating: musicnet/musicnet/train_labels/2119.csv
#   inflating: musicnet/musicnet/train_labels/2127.csv
#   inflating: musicnet/musicnet/train_labels/2131.csv
#   inflating: musicnet/musicnet/train_labels/2138.csv
#   inflating: musicnet/musicnet/train_labels/2140.csv
#   inflating: musicnet/musicnet/train_labels/2147.csv
#   inflating: musicnet/musicnet/train_labels/2148.csv
#   inflating: musicnet/musicnet/train_labels/2149.csv
#   inflating: musicnet/musicnet/train_labels/2150.csv
#   inflating: musicnet/musicnet/train_labels/2151.csv
#   inflating: musicnet/musicnet/train_labels/2154.csv
#   inflating: musicnet/musicnet/train_labels/2155.csv
#   inflating: musicnet/musicnet/train_labels/2156.csv
#   inflating: musicnet/musicnet/train_labels/2157.csv
#   inflating: musicnet/musicnet/train_labels/2158.csv
#   inflating: musicnet/musicnet/train_labels/2159.csv
#   inflating: musicnet/musicnet/train_labels/2160.csv
#   inflating: musicnet/musicnet/train_labels/2161.csv
#   inflating: musicnet/musicnet/train_labels/2166.csv
#   inflating: musicnet/musicnet/train_labels/2167.csv
#   inflating: musicnet/musicnet/train_labels/2168.csv
#   inflating: musicnet/musicnet/train_labels/2169.csv
#   inflating: musicnet/musicnet/train_labels/2177.csv
#   inflating: musicnet/musicnet/train_labels/2178.csv
#   inflating: musicnet/musicnet/train_labels/2179.csv
#   inflating: musicnet/musicnet/train_labels/2180.csv
#   inflating: musicnet/musicnet/train_labels/2186.csv
#   inflating: musicnet/musicnet/train_labels/2194.csv
#   inflating: musicnet/musicnet/train_labels/2195.csv
#   inflating: musicnet/musicnet/train_labels/2196.csv
#   inflating: musicnet/musicnet/train_labels/2198.csv
#   inflating: musicnet/musicnet/train_labels/2200.csv
#   inflating: musicnet/musicnet/train_labels/2201.csv
#   inflating: musicnet/musicnet/train_labels/2202.csv
#   inflating: musicnet/musicnet/train_labels/2203.csv
#   inflating: musicnet/musicnet/train_labels/2204.csv
#   inflating: musicnet/musicnet/train_labels/2207.csv
#   inflating: musicnet/musicnet/train_labels/2208.csv
#   inflating: musicnet/musicnet/train_labels/2209.csv
#   inflating: musicnet/musicnet/train_labels/2210.csv
#   inflating: musicnet/musicnet/train_labels/2211.csv
#   inflating: musicnet/musicnet/train_labels/2212.csv
#   inflating: musicnet/musicnet/train_labels/2213.csv
#   inflating: musicnet/musicnet/train_labels/2214.csv
#   inflating: musicnet/musicnet/train_labels/2215.csv
#   inflating: musicnet/musicnet/train_labels/2217.csv
#   inflating: musicnet/musicnet/train_labels/2218.csv
#   inflating: musicnet/musicnet/train_labels/2219.csv
#   inflating: musicnet/musicnet/train_labels/2220.csv
#   inflating: musicnet/musicnet/train_labels/2221.csv
#   inflating: musicnet/musicnet/train_labels/2222.csv
#   inflating: musicnet/musicnet/train_labels/2224.csv
#   inflating: musicnet/musicnet/train_labels/2225.csv
#   inflating: musicnet/musicnet/train_labels/2227.csv
#   inflating: musicnet/musicnet/train_labels/2228.csv
#   inflating: musicnet/musicnet/train_labels/2229.csv
#   inflating: musicnet/musicnet/train_labels/2230.csv
#   inflating: musicnet/musicnet/train_labels/2231.csv
#   inflating: musicnet/musicnet/train_labels/2232.csv
#   inflating: musicnet/musicnet/train_labels/2234.csv
#   inflating: musicnet/musicnet/train_labels/2237.csv
#   inflating: musicnet/musicnet/train_labels/2238.csv
#   inflating: musicnet/musicnet/train_labels/2239.csv
#   inflating: musicnet/musicnet/train_labels/2240.csv
#   inflating: musicnet/musicnet/train_labels/2241.csv
#   inflating: musicnet/musicnet/train_labels/2242.csv
#   inflating: musicnet/musicnet/train_labels/2243.csv
#   inflating: musicnet/musicnet/train_labels/2244.csv
#   inflating: musicnet/musicnet/train_labels/2247.csv
#   inflating: musicnet/musicnet/train_labels/2248.csv
#   inflating: musicnet/musicnet/train_labels/2282.csv
#   inflating: musicnet/musicnet/train_labels/2283.csv
#   inflating: musicnet/musicnet/train_labels/2284.csv
#   inflating: musicnet/musicnet/train_labels/2285.csv
#   inflating: musicnet/musicnet/train_labels/2288.csv
#   inflating: musicnet/musicnet/train_labels/2289.csv
#   inflating: musicnet/musicnet/train_labels/2292.csv
#   inflating: musicnet/musicnet/train_labels/2293.csv
#   inflating: musicnet/musicnet/train_labels/2294.csv
#   inflating: musicnet/musicnet/train_labels/2295.csv
#   inflating: musicnet/musicnet/train_labels/2296.csv
#   inflating: musicnet/musicnet/train_labels/2297.csv
#   inflating: musicnet/musicnet/train_labels/2300.csv
#   inflating: musicnet/musicnet/train_labels/2302.csv
#   inflating: musicnet/musicnet/train_labels/2304.csv
#   inflating: musicnet/musicnet/train_labels/2305.csv
#   inflating: musicnet/musicnet/train_labels/2307.csv
#   inflating: musicnet/musicnet/train_labels/2308.csv
#   inflating: musicnet/musicnet/train_labels/2310.csv
#   inflating: musicnet/musicnet/train_labels/2313.csv
#   inflating: musicnet/musicnet/train_labels/2314.csv
#   inflating: musicnet/musicnet/train_labels/2315.csv
#   inflating: musicnet/musicnet/train_labels/2318.csv
#   inflating: musicnet/musicnet/train_labels/2319.csv
#   inflating: musicnet/musicnet/train_labels/2320.csv
#   inflating: musicnet/musicnet/train_labels/2322.csv
#   inflating: musicnet/musicnet/train_labels/2325.csv
#   inflating: musicnet/musicnet/train_labels/2330.csv
#   inflating: musicnet/musicnet/train_labels/2334.csv
#   inflating: musicnet/musicnet/train_labels/2335.csv
#   inflating: musicnet/musicnet/train_labels/2336.csv
#   inflating: musicnet/musicnet/train_labels/2341.csv
#   inflating: musicnet/musicnet/train_labels/2342.csv
#   inflating: musicnet/musicnet/train_labels/2343.csv
#   inflating: musicnet/musicnet/train_labels/2345.csv
#   inflating: musicnet/musicnet/train_labels/2346.csv
#   inflating: musicnet/musicnet/train_labels/2348.csv
#   inflating: musicnet/musicnet/train_labels/2350.csv
#   inflating: musicnet/musicnet/train_labels/2357.csv
#   inflating: musicnet/musicnet/train_labels/2358.csv
#   inflating: musicnet/musicnet/train_labels/2359.csv
#   inflating: musicnet/musicnet/train_labels/2364.csv
#   inflating: musicnet/musicnet/train_labels/2365.csv
#   inflating: musicnet/musicnet/train_labels/2366.csv
#   inflating: musicnet/musicnet/train_labels/2368.csv
#   inflating: musicnet/musicnet/train_labels/2371.csv
#   inflating: musicnet/musicnet/train_labels/2372.csv
#   inflating: musicnet/musicnet/train_labels/2373.csv
#   inflating: musicnet/musicnet/train_labels/2374.csv
#   inflating: musicnet/musicnet/train_labels/2376.csv
#   inflating: musicnet/musicnet/train_labels/2377.csv
#   inflating: musicnet/musicnet/train_labels/2379.csv
#   inflating: musicnet/musicnet/train_labels/2381.csv
#   inflating: musicnet/musicnet/train_labels/2383.csv
#   inflating: musicnet/musicnet/train_labels/2384.csv
#   inflating: musicnet/musicnet/train_labels/2388.csv
#   inflating: musicnet/musicnet/train_labels/2389.csv
#   inflating: musicnet/musicnet/train_labels/2390.csv
#   inflating: musicnet/musicnet/train_labels/2391.csv
#   inflating: musicnet/musicnet/train_labels/2392.csv
#   inflating: musicnet/musicnet/train_labels/2393.csv
#   inflating: musicnet/musicnet/train_labels/2397.csv
#   inflating: musicnet/musicnet/train_labels/2398.csv
#   inflating: musicnet/musicnet/train_labels/2403.csv
#   inflating: musicnet/musicnet/train_labels/2404.csv
#   inflating: musicnet/musicnet/train_labels/2405.csv
#   inflating: musicnet/musicnet/train_labels/2406.csv
#   inflating: musicnet/musicnet/train_labels/2410.csv
#   inflating: musicnet/musicnet/train_labels/2411.csv
#   inflating: musicnet/musicnet/train_labels/2415.csv
#   inflating: musicnet/musicnet/train_labels/2417.csv
#   inflating: musicnet/musicnet/train_labels/2420.csv
#   inflating: musicnet/musicnet/train_labels/2422.csv
#   inflating: musicnet/musicnet/train_labels/2423.csv
#   inflating: musicnet/musicnet/train_labels/2424.csv
#   inflating: musicnet/musicnet/train_labels/2431.csv
#   inflating: musicnet/musicnet/train_labels/2432.csv
#   inflating: musicnet/musicnet/train_labels/2433.csv
#   inflating: musicnet/musicnet/train_labels/2436.csv
#   inflating: musicnet/musicnet/train_labels/2441.csv
#   inflating: musicnet/musicnet/train_labels/2442.csv
#   inflating: musicnet/musicnet/train_labels/2443.csv
#   inflating: musicnet/musicnet/train_labels/2444.csv
#   inflating: musicnet/musicnet/train_labels/2451.csv
#   inflating: musicnet/musicnet/train_labels/2462.csv
#   inflating: musicnet/musicnet/train_labels/2463.csv
#   inflating: musicnet/musicnet/train_labels/2466.csv
#   inflating: musicnet/musicnet/train_labels/2471.csv
#   inflating: musicnet/musicnet/train_labels/2472.csv
#   inflating: musicnet/musicnet/train_labels/2473.csv
#   inflating: musicnet/musicnet/train_labels/2476.csv
#   inflating: musicnet/musicnet/train_labels/2477.csv
#   inflating: musicnet/musicnet/train_labels/2478.csv
#   inflating: musicnet/musicnet/train_labels/2480.csv
#   inflating: musicnet/musicnet/train_labels/2481.csv
#   inflating: musicnet/musicnet/train_labels/2482.csv
#   inflating: musicnet/musicnet/train_labels/2483.csv
#   inflating: musicnet/musicnet/train_labels/2486.csv
#   inflating: musicnet/musicnet/train_labels/2487.csv
#   inflating: musicnet/musicnet/train_labels/2488.csv
#   inflating: musicnet/musicnet/train_labels/2490.csv
#   inflating: musicnet/musicnet/train_labels/2491.csv
#   inflating: musicnet/musicnet/train_labels/2492.csv
#   inflating: musicnet/musicnet/train_labels/2494.csv
#   inflating: musicnet/musicnet/train_labels/2497.csv
#   inflating: musicnet/musicnet/train_labels/2501.csv
#   inflating: musicnet/musicnet/train_labels/2502.csv
#   inflating: musicnet/musicnet/train_labels/2504.csv
#   inflating: musicnet/musicnet/train_labels/2505.csv
#   inflating: musicnet/musicnet/train_labels/2506.csv
#   inflating: musicnet/musicnet/train_labels/2507.csv
#   inflating: musicnet/musicnet/train_labels/2509.csv
#   inflating: musicnet/musicnet/train_labels/2510.csv
#   inflating: musicnet/musicnet/train_labels/2512.csv
#   inflating: musicnet/musicnet/train_labels/2514.csv
#   inflating: musicnet/musicnet/train_labels/2516.csv
#   inflating: musicnet/musicnet/train_labels/2521.csv
#   inflating: musicnet/musicnet/train_labels/2522.csv
#   inflating: musicnet/musicnet/train_labels/2523.csv
#   inflating: musicnet/musicnet/train_labels/2527.csv
#   inflating: musicnet/musicnet/train_labels/2528.csv
#   inflating: musicnet/musicnet/train_labels/2529.csv
#   inflating: musicnet/musicnet/train_labels/2530.csv
#   inflating: musicnet/musicnet/train_labels/2531.csv
#   inflating: musicnet/musicnet/train_labels/2532.csv
#   inflating: musicnet/musicnet/train_labels/2533.csv
#   inflating: musicnet/musicnet/train_labels/2537.csv
#   inflating: musicnet/musicnet/train_labels/2538.csv
#   inflating: musicnet/musicnet/train_labels/2540.csv
#   inflating: musicnet/musicnet/train_labels/2542.csv
#   inflating: musicnet/musicnet/train_labels/2550.csv
#   inflating: musicnet/musicnet/train_labels/2555.csv
#   inflating: musicnet/musicnet/train_labels/2557.csv
#   inflating: musicnet/musicnet/train_labels/2560.csv
#   inflating: musicnet/musicnet/train_labels/2562.csv
#   inflating: musicnet/musicnet/train_labels/2564.csv
#   inflating: musicnet/musicnet/train_labels/2566.csv
#   inflating: musicnet/musicnet/train_labels/2567.csv
#   inflating: musicnet/musicnet/train_labels/2568.csv
#   inflating: musicnet/musicnet/train_labels/2570.csv
#   inflating: musicnet/musicnet/train_labels/2571.csv
#   inflating: musicnet/musicnet/train_labels/2572.csv
#   inflating: musicnet/musicnet/train_labels/2573.csv
#   inflating: musicnet/musicnet/train_labels/2575.csv
#   inflating: musicnet/musicnet/train_labels/2576.csv
#   inflating: musicnet/musicnet/train_labels/2581.csv
#   inflating: musicnet/musicnet/train_labels/2582.csv
#   inflating: musicnet/musicnet/train_labels/2586.csv
#   inflating: musicnet/musicnet/train_labels/2588.csv
#   inflating: musicnet/musicnet/train_labels/2590.csv
#   inflating: musicnet/musicnet/train_labels/2591.csv
#   inflating: musicnet/musicnet/train_labels/2593.csv
#   inflating: musicnet/musicnet/train_labels/2594.csv
#   inflating: musicnet/musicnet/train_labels/2595.csv
#   inflating: musicnet/musicnet/train_labels/2596.csv
#   inflating: musicnet/musicnet/train_labels/2603.csv
#   inflating: musicnet/musicnet/train_labels/2607.csv
#   inflating: musicnet/musicnet/train_labels/2608.csv
#   inflating: musicnet/musicnet/train_labels/2611.csv
#   inflating: musicnet/musicnet/train_labels/2614.csv
#   inflating: musicnet/musicnet/train_labels/2618.csv
#   inflating: musicnet/musicnet/train_labels/2619.csv
#   inflating: musicnet/musicnet/train_labels/2620.csv
#   inflating: musicnet/musicnet/train_labels/2621.csv
#   inflating: musicnet/musicnet/train_labels/2622.csv
#   inflating: musicnet/musicnet/train_labels/2626.csv
#   inflating: musicnet/musicnet/train_labels/2627.csv
#   inflating: musicnet/musicnet/train_labels/2629.csv
#   inflating: musicnet/musicnet/train_labels/2632.csv
#   inflating: musicnet/musicnet/train_labels/2633.csv
#   inflating: musicnet/musicnet/train_labels/2659.csv
#   inflating: musicnet/musicnet/train_labels/2677.csv
#   inflating: musicnet/musicnet/train_labels/2678.csv
#   inflating: musicnet_metadata.csv
#   inflating: musicnet_midis/musicnet_midis/Bach/2186_vs6_1.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2191_vs6_5.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2194_prelude13.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2195_fugue3.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2196_prelude3.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2198_fugue22.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2200_fugue16.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2201_prelude16.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2202_fp-1all.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2203_fp-2cou.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2204_fp-3sar.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2207_fugue10.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2208_prelude10.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2209_fugue4.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2210_prelude4.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2211_fugue12.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2212_prelude12.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2213_fugue2.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2214_prelude2.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2215_fugue1.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2217_cs3-1pre.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2218_cs3-2all.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2219_cs3-3cou.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2220_cs3-4sar.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2221_cs3-5bou.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2222_cs3-6gig.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2224_fugue7.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2225_prelude7.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2227_fugue6.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2228_prelude6.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2229_fugue20.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2230_prelude20.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2231_fugue21.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2232_prelude21.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2234_prelude11.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2237_fugue23.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2238_prelude23.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2239_fugue17.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2240_prelude17.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2241_vs1_1.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2242_vs1_2.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2243_vs1_3.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2244_vs1_4.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2247_fugue9.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2248_prelude9.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2282_vhs1_1.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2283_vhs1_2.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2284_vhs1_3.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2285_vhs1_4.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2288_vs2_2.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2289_vs2_3.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2292_prelude19.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2293_cs4-1pre.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2294_cs4-2all.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2295_cs4-3cou.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2296_cs4-4sar.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2297_cs4-5bou.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2298_cs4-6gig.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2300_prelude8.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2302_fugue5.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2303_prelude5.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2304_fugue14.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2305_prelude14.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2307_fugue18.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2308_prelude18.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2310_prelude15.mid
#   inflating: musicnet_midis/musicnet_midis/Bach/2659_vs2_6.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2313_qt15_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2314_qt15_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2315_qt15_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2318_bh38m1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2319_bh38m2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2320_bh38m3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2322_ps23_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2325_ps23_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2330_lvb12n1a.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2334_vns08_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2335_vns08_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2336_vns08_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2341_vns08_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2342_vns08_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2343_ps14_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2345_ps14_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2346_ps14_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2348_ps14_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2350_ps14_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2357_ps15_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2358_ps15_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2359_ps15_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2364_ps15_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2365_qt12_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2366_qt12_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2368_qt12_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2371_ps09_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2372_ps09_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2373_ps19_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2374_ps19_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2376_qt08_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2377_qt08_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2379_qt08_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2381_qt13_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2382_qt13_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2383_qt13_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2384_qt13_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2388_ps17_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2389_ps17_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2390_ps17_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2391_ps17_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2392_ps17_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2393_ps17_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2397_op47_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2398_op47_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2403_qt01_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2404_ps31_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2405_ps31_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2406_ps31_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2410_ps13_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2411_ps13_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2415_lvbsext2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2416_lvbsext3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2417_lvbsext4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2420_lvb12n2c.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2422_ps01_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2423_ps01_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2424_ps01_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2431_qt16_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2432_qt16_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2433_qt16_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2436_ps21_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2441_ps29_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2442_ps29_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2443_ps29_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2444_ps29_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2451_qt06_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2462_lvb23b.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2463_lvb23c.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2466_lvb23c.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2471_ps03_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2472_ps03_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2473_ps03_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2476_ps03_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2477_ps03_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2478_ps03_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2480_qt05_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2481_qt05_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2482_qt05_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2483_qt05_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2486_ps04_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2487_ps04_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2488_ps04_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2490_ps04_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2491_ps04_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2492_ps04_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2494_qt11_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2497_qt11_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2501_lvb12n3b.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2502_lvb12n3c.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2504_op103-1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2505_op103-2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2506_op103-3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2507_op103-4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2509_ps02_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2510_ps02_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2512_ps02_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2514_ps02_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2516_ps02_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2521_vcs3_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2522_vcs3_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2523_vcs3_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2527_ps05_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2528_ps05_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2529_ps05_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2530_ps32_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2531_ps32_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2532_ps32_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2533_ps32_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2537_ps20_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2538_ps20_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2540_ps28_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2542_ps28_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2550_ps24_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2555_ps30_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2556_ps30_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2557_ps30_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2560_qt02_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2562_qt02_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2564_ps11_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2566_ps11_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2567_ps27_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2568_ps27_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2570_bevs7a.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2571_bevs7b.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2572_bevs7c.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2573_bevs7d.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2575_ps08_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2576_ps08_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2581_ps22_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2582_ps22_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2586_vcs4_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2588_ps12_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2590_ps12_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2591_ps12_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2593_ps18_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2594_ps18_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2595_ps18_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2596_ps18_04.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2603_ps26_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2607_ps16_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2608_ps16_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2611_ps07_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2614_ps07_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2618_ps06_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2619_ps06_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2620_ps06_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2621_qt07_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2622_qt07_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2626_vns10_1.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2627_vns10_2.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2628_vns10_3.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2629_vns10_4.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2632_ps10_02.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2633_ps10_03.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2677_ps09_01.mid
#   inflating: musicnet_midis/musicnet_midis/Beethoven/2678_ps10_01.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2112_jb38_1.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2113_jb38_2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2114_jb38_3.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2116_brahms_sonata_opus_120-1.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2117_brahms_sonata_opus_120-2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2118_brahms_sonata_opus_120-3.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2119_brahms_sonata_opus_120-4.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2127_bra11-2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2131_bra11-6.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2138_br51n1m2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2140_br51n1m4.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2147_br36m4.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2148_br25m1.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2149_br25m2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2150_br25m3.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2151_br25m4.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2154_br18m1.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2155_br18m2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2156_br18m3.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2157_br18m4.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2158_bra40_1.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2159_bra40_2.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2160_bra40_3.mid
#   inflating: musicnet_midis/musicnet_midis/Brahms/2161_bra40_4.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2075_quintBb1.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2076_quintBb2.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2077_quintBb3.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2078_quint2d1.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2079_quint2d2.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2080_quint2d3.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2081_quint3f1.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2082_quint3f2.mid
#   inflating: musicnet_midis/musicnet_midis/Cambini/2083_quint3f3.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1916_dvq10m1.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1918_dvqt10m3.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1919_dvqt10m4.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1922_dvqt10m3.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1923_dvqt10m4.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1931_dv96_2.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1932_dv96_3.mid
#   inflating: musicnet_midis/musicnet_midis/Dvorak/1933_dv96_4.mid
#   inflating: musicnet_midis/musicnet_midis/Faure/2166_gr_f45m1.mid
#   inflating: musicnet_midis/musicnet_midis/Faure/2167_gr_f45m2.mid
#   inflating: musicnet_midis/musicnet_midis/Faure/2168_gr_f45m3.mid
#   inflating: musicnet_midis/musicnet_midis/Faure/2169_gr_f45m4.mid
#   inflating: musicnet_midis/musicnet_midis/Haydn/2104_op64n5_1.mid
#   inflating: musicnet_midis/musicnet_midis/Haydn/2105_op64n5_2.mid
#   inflating: musicnet_midis/musicnet_midis/Haydn/2106_op64n5_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1788_kv_465_1.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1789_kv_465_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1790_kv_465_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1791_kv_465_4.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1792_kv_465_1.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1793_kv_465_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1805_kv_387_1.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1807_kv_387_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1811_kv581b.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1812_kv581c.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1813_kv581d.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1817_k3752.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1818_k3753.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1819_k3754a.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1822_kv_421_1.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1824_kv_421_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1828_k542_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1829_k542_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1835_kv_590_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1859_kv_464_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1872_k502_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1873_k502_3.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1876_k496_2.mid
#   inflating: musicnet_midis/musicnet_midis/Mozart/1893_k564_3.mid
#   inflating: musicnet_midis/musicnet_midis/Ravel/2177_gr_rqtf1.mid
#   inflating: musicnet_midis/musicnet_midis/Ravel/2178_gr_rqtf2.mid
#   inflating: musicnet_midis/musicnet_midis/Ravel/2179_gr_rqtf3.mid
#   inflating: musicnet_midis/musicnet_midis/Ravel/2180_gr_rqtf4.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1727_schubert_op114_2.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1728_schubert_op114_3.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1729_schubert_op114_4.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1730_schubert_op114_5.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1733_sy_sps92.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1734_sy_sps93.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1735_sy_sps94.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1739_sb99m4.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1742_sb163m2.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1749_sy_sps11.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1750_sy_sps12.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1751_sy_sps13.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1752_sy_sps14.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1755_sy_sps52.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1756_sy_sps53.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1757_d958-1.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1758_d958-2.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1759_d958-3.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1760_d958-4.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1763_scbt1421.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1764_scbt1422.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1765_scbt1423.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1766_scbt1424.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1768_sy_sps32.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1771_sy_sps41.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1772_sy_sps42.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1773_sy_sps43.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1775_sy_sps21.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1776_sy_sps22.mid
#   inflating: musicnet_midis/musicnet_midis/Schubert/1777_sy_sps23.mid

# %%
fs = 44100      # samples/second

# %%
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-23-960daa6117fa> in <module>()
# ----> 1 train_data = np.load(final_file, encoding = 'latin1')
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     430             stack.pop_all()
#     431             ret = NpzFile(fid, own_fid=own_fid, allow_pickle=allow_pickle,
# --> 432                           pickle_kwargs=pickle_kwargs)
#     433             return ret
#     434         elif magic == format.MAGIC_PREFIX:
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in __init__(self, fid, own_fid, allow_pickle, pickle_kwargs)
#     184         # Import is postponed to here since zipfile depends on gzip, an
#     185         # optional component of the so-called standard library.
# --> 186         _zip = zipfile_factory(fid)
#     187         self._files = _zip.namelist()
#     188         self.files = []
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in zipfile_factory(file, *args, **kwargs)
#     110     import zipfile
#     111     kwargs['allowZip64'] = True
# --> 112     return zipfile.ZipFile(file, *args, **kwargs)
#     113
#     114
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
#    1324         if not endrec:
# -> 1325             raise BadZipFile("File is not a zip file")
#    1326         if self.debug > 1:
#    1327             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-21cef2171bd7> in <module>()
# ----> 1 final_file = fixBadZipfile('/content/musicnet.npz')
#
# <ipython-input-13-0b00043d973a> in fixBadZipfile(zipFile)
#       2  f = open(zipFile, 'r+b')
#       3  data = f.read()
# ----> 4  pos = data.find('\x50\x4b\x05\x06') # End of central directory signature
#       5  if (pos > 0):
#       6      self._log("Trancating file at location " + str(pos + 22)+ ".")
#
# TypeError: argument should be integer or bytes-like object, not 'str'
