# %% [markdown]
# ### 1. Importing all the libraries, checking for Tensorflow 2 and setting the seeds

# %%
#imports and Drive mounting
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd
import os

# fix random seed for reproducibility
seed = 2020
np.random.seed(seed)  

from sklearn.model_selection import train_test_split

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, AveragePooling2D
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras import regularizers
# Out:
# 2.4.1

# %% [markdown]
# ### 2. Helper functions for the visualisation

# %%
#helper functions for visualisation

# same function as before - feel free to customize if you want!

def plot_history(history):
  plt.figure(figsize = (12,4))
  plt.subplot(1,2,1)

  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(history.epoch, np.array(history.history['accuracy']),'g-',
           label='Train accuracy')
  plt.plot(history.epoch, np.array(history.history['val_accuracy']),'r-',
           label = 'Validation accuracy')
  plt.ylim([0.0,1.0])
  plt.legend()

  plt.subplot(1,2,2)
  plt.xlabel('Epoch')
  plt.ylabel('Loss minimised by model')
  plt.plot(history.epoch, np.array(history.history['loss']),'g-',
           label='Train loss')
  plt.plot(history.epoch, np.array(history.history['val_loss']),'r-',
           label = 'Validation loss')
  plt.legend()

# %% [markdown]
# ### 3. Mounting your Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os

# !ls '/content/gdrive/My Drive/'
# Out:
# Mounted at /content/gdrive
# 'AAA Clean Room'	 'Copy of GA2_Training_v8.ipynb'
#  AI_pract3_nn2020	  DGM
#  Assignments		 'DL1 Logbook.gdoc'
# 'Code Explanation.gdoc'   First_graded_assignment_analysis.ipynb
# 'Colab Notebooks'	  foo.txt

# %% [markdown]
# ### 4. Loading the data

# %%
# Load the data: CIFAR100 with 20 class labels
(x_train_all, r_train_all_class), (x_test , r_test_class ) = cifar100.load_data(label_mode='coarse')

num_classes = 20

val_size = 6000
# make validation set
x_train, x_val, r_train_class, r_val_class = train_test_split(x_train_all, r_train_all_class, test_size=val_size, random_state=0)

# let's again take a subset of the training data first, for playing around
# Note that such a subset is only useful if it can guide your tuning process,
# i.e., if it leads you to similar decisions as you would make on the whole training set

# You can again use a subset of the training data for initial exploration
# In this case, 10000 samples is really too small, so we suggest 20000

x_train_small = x_train[:20000]
r_train_small_class = r_train_class[:20000]

# And we do the same standardization as in the first assignment
x_train_all = x_train_all.astype('float32') #All the training samples
x_train = x_train.astype('float32') #All the training samples, without the validation samples
x_train_small = x_train_small.astype('float32') #Part of the training samples
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')

x_train_all /= 255.0
x_train /= 255.0
x_train_small /= 255.0
x_val /= 255.0
x_test /= 255.0

# the labels from the downloaded data are integer numbers
# for a multi-class classification task, we again convert each integer
# to a vector with 19 zeros and a single '1', corresponding to the right class
r_train_all = tf.keras.utils.to_categorical(r_train_all_class, num_classes)
r_train = tf.keras.utils.to_categorical(r_train_class, num_classes)
r_train_small = tf.keras.utils.to_categorical(r_train_small_class, num_classes)
r_val = tf.keras.utils.to_categorical(r_val_class, num_classes)
r_test = tf.keras.utils.to_categorical(r_test_class, num_classes)

# Labels
labels = [
'aquatic mammals',
'fish',
'flowers',
'food containers',
'fruit and vegetables',
'household electrical devices',
'household furniture',
'insects',
'large carnivores',
'large man-made outdoor things',
'large natural outdoor scenes',
'large omnivores and herbivores',
'medium-sized mammals',
'non-insect invertebrates',
'people',
'reptiles',
'small mammals',
'trees',
'vehicles 1',
'vehicles 2'
]

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step
# x_train shape: (44000, 32, 32, 3)
# 44000 train samples
# 6000 validation samples
# 10000 test samples

# %% [markdown]
# ###5. Visualisation of a few training samples

# %%
f = plt.figure(figsize=(20,10))
for idx in range(15):
    plt.subplot(3,5,idx+1)
    plt.subplots_adjust(hspace=0.5)
    plt.title(labels[r_train_class[idx,0]])
    plt.imshow(x_train[idx],  interpolation='None')

# %% [markdown]
# ###6. Create initial model without regularization

# %%
def initial_model():
  model = Sequential()

  # Convolutional layers
  model.add(Conv2D(64, (3, 3), padding='same',input_shape=x_train.shape[1:]))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  model.add(Conv2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(128, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
 
  model.add(Conv2D(512, (3, 3), padding='same'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(512, (3, 3)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  
  # end of convolutional layers, start of 'hidden' dense layers (can be more than 1 if necessary)
  model.add(Flatten())
  model.add(Dense(512))
  model.add(Activation('relu'))
 
  # Final dense layer = linear classifier
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
 
  opt = tf.keras.optimizers.Adam(learning_rate = 0.00025) #using defaults for now
 
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
 
  return model

# %% [markdown]
# ###7. Training and checking the power of our initial model

# %%
batch_size = 512
epochs = 30

# checkpoint and early stopping code from first assignment is introduced in comments:
# use or replace by your preferred workflow 
# do not forget to reload best model for evaluation after using early stopping (re-use code from first assignment)

model_1 = initial_model()
model_1.summary()

history_1 = model_1.fit(x_train, r_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_val, r_val),
          shuffle=True)

# Run code below to save the weights of final trained model:
# (not very useful in combination with modelcheckpoint, because then you would revert to the best model afterwards)
#model_1.save_weights(model_savename)

# We analyse the result:

[train_loss, train_accuracy] = model_1.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.4f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model_1.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.4f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))

#Now we visualise what happened during training
plot_history(history_1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_48 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_49 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_50 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_51 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 8, 8, 512)         590336
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_52 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_53 (Activation)   (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# activation_54 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None,
# 86/86 [==============================] - 14s 158ms/step - loss: 0.0059 - accuracy: 0.9998 - val_loss: 1.9056 - val_accuracy: 0.5630
# Epoch 22/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.0037 - accuracy: 0.9999 - val_loss: 1.8269 - val_accuracy: 0.5737
# Epoch 23/30
# 86/86 [==============================] - 14s 157ms/step - loss: 0.0056 - accuracy: 0.9998 - val_loss: 1.8674 - val_accuracy: 0.5692
# Epoch 24/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.0057 - accuracy: 0.9998 - val_loss: 1.8652 - val_accuracy: 0.5717
# Epoch 25/30
# 86/86 [==============================] - 14s 157ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 1.8486 - val_accuracy: 0.5767
# Epoch 26/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.0030 - accuracy: 0.9999 - val_loss: 1.8753 - val_accuracy: 0.5750
# Epoch 27/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 1.9181 - val_accuracy: 0.5688
# Epoch 28/30
# 86/86 [==============================] - 14s 157ms/step - loss: 0.1198 - accuracy: 0.9701 - val_loss: 5.2080 - val_accuracy: 0.2348
# Epoch 29/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.8938 - accuracy: 0.7119 - val_loss: 2.1249 - val_accuracy: 0.4703
# Epoch 30/30
# 86/86 [==============================] - 14s 158ms/step - loss: 0.2237 - accuracy: 0.9439 - val_loss: 1.7221 - val_accuracy: 0.5315
# Training set Accuracy: 0.9821
# Training set Loss: 0.1148
#
# Validation set Accuracy: 0.5315
# Validation set Loss: 1.7221

# %% [markdown]
# ###8. Adding regularisation to the initial model

# %%
def initial_model():
  model = Sequential()
  maxnorm_conv2D = 1
  maxnorm_dense = 1
  l1 = 1e-6
  l2 = 1e-3
 
  # Convolutional layers
  model.add(Conv2D(64, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2),input_shape=x_train.shape[1:]))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(64, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.3))
  
  model.add(Conv2D(128, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(128, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.4))
 
  model.add(Conv2D(512, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Conv2D(512, (3, 3), padding='same', kernel_constraint=max_norm(maxnorm_conv2D), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.6))
  
  # end of convolutional layers, start of 'hidden' dense layers (can be more than 1 if necessary)
  model.add(Flatten())
  model.add(Dense(512, kernel_constraint=max_norm(maxnorm_dense), kernel_regularizer=regularizers.L1L2(l1= l1, l2= l2)))
  model.add(Activation('relu'))
  model.add(Dropout(0.6))
 
  # Final dense layer = linear classifier
  model.add(Dense(num_classes))
  model.add(Activation('softmax'))
 
  opt = tf.keras.optimizers.Adam(learning_rate = 0.00025) #using defaults for now
 
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
 
  return model

# %% [markdown]
# ### 9. Training and evaluating the regularised model

# %%
batch_size = 512
epochs = 150

# checkpoint and early stopping code from first assignment is introduced in comments:
# use or replace by your preferred workflow 
# do not forget to reload best model for evaluation after using early stopping (re-use code from first assignment)

checkpoint_dir = "/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/"
print("Models will be saved in ",checkpoint_dir)
model_savename = checkpoint_dir+"initialmodel_model_version_0.1.h5"
checkpoint_path = checkpoint_dir+"cp-{epoch:04d}.ckpt"


model_1 = initial_model()
model_1.summary()

#code for modelcheckpoint and early stopping  commented below
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, 
                                                monitor='val_accuracy',
                                                save_weights_only=True,
                                                save_best_only=True,
                                                verbose=1)

stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=15,min_delta=0.0001)

history_1 = model_1.fit(x_train, r_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_val, r_val),
         callbacks = [stopping_callback, cp_callback],
          shuffle=True)

model_1.save_weights(model_savename)

# We analyse the result:

[train_loss, train_accuracy] = model_1.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.4f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = model_1.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.4f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))

#Now we visualise what happened during training
plot_history(history_1)
# Out:
# Models will be saved in  /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_56 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_57 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_58 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_59 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 8, 8, 512)         590336
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# activation_62 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                10260
# _________________________________________________________________
# activation_63 (Activation)   (None, 20)                0
# =================================================================
# Total params: 7,421,012
# Trainable params: 7,418,196
# Non-trainable params: 2,816
# _________________________________________________________________
# Epoch 1/150
# 86/86 [==============================] - 17s 173ms/step - loss: 5.1192 - accuracy: 0.0633 - val_loss: 4.5388 - val_accuracy: 0.0528
#
# Epoch 00001: val_accuracy improved from -inf to 0.05283, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0001.ckpt
# Epoch 2/150
# 86/86 [==============================] - 15s 170ms/step - loss: 4.3684 - accuracy: 0.1101 - val_loss: 4.4783 - val_accuracy: 0.0668
#
# Epoch 00002: val_accuracy improved from 0.05283 to 0.06683, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0002.ckpt
# Epoch 3/150
# 86/86 [==============================] - 15s 170ms/step - loss: 4.1003 - accuracy: 0.1620 - val_loss: 4.4525 - val_accuracy: 0.0928
#
# Epoch 00003: val_accuracy improved from 0.06683 to 0.09283, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0003.ckpt
# Epoch 4/150
# 86/86 [==============================] - 15s 170ms/step - loss: 3.8848 - accuracy: 0.1875 - val_loss: 4.2366 - val_accuracy: 0.0830
#
# Epoch 00004: val_accuracy did not improve from 0.09283
# Epoch 5/150
# 86/86 [==============================] - 15s 169ms/step - loss: 3.6737 - accuracy: 0.2160 - val_loss: 4.0101 - val_accuracy: 0.1262
#
# Epoch 00005: val_accuracy improved from 0.09283 to 0.12617, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0005.ckpt
# Epoch 6/150
# 86/86 [==============================] - 15s 170ms/step - loss: 3.4622 - accuracy: 0.2413 - val_loss: 3.6778 - val_accuracy: 0.1807
#
# Epoch 00006: val_accuracy improved from 0.12617 to 0.18067, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0006.ckpt
# Epoch 7/150
# 86/86 [==============================] - 15s 170ms/step - loss: 3.2645 - accuracy: 0.2709 - val_loss: 3.4950 - val_accuracy: 0.2092
#
# Epoch 00007: val_accuracy improved from 0.18067 to 0.20917, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0007.ckpt
# Epoch 8/150
# 86/86 [==============================] - 15s 170ms/step - loss: 3.0819 - accuracy: 0.2984 - val_loss: 3.5310 - val_accuracy: 0.2137
#
# Epoch 00008: val_accuracy improved from 0.20917 to 0.21367, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0008.ckpt
# Epoch 9/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.9192 - accuracy: 0.3243 - val_loss: 3.2900 - val_accuracy: 0.2610
#
# Epoch 00009: val_accuracy improved from 0.21367 to 0.26100, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0009.ckpt
# Epoch 10/150
# 86/86 [==============================] - 15s 169ms/step - loss: 2.7770 - accuracy: 0.3429 - val_loss: 2.6377 - val_accuracy: 0.3830
#
# Epoch 00010: val_accuracy improved from 0.26100 to 0.38300, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0010.ckpt
# Epoch 11/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.6501 - accuracy: 0.3660 - val_loss: 2.5859 - val_accuracy: 0.3960
#
# Epoch 00011: val_accuracy improved from 0.38300 to 0.39600, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0011.ckpt
# Epoch 12/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.5240 - accuracy: 0.3931 - val_loss: 2.5766 - val_accuracy: 0.3817
#
# Epoch 00012: val_accuracy did not improve from 0.39600
# Epoch 13/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.4378 - accuracy: 0.4063 - val_loss: 2.1681 - val_accuracy: 0.4768
#
# Epoch 00013: val_accuracy improved from 0.39600 to 0.47683, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0013.ckpt
# Epoch 14/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.3287 - accuracy: 0.4272 - val_loss: 2.1748 - val_accuracy: 0.4685
#
# Epoch 00014: val_accuracy did not improve from 0.47683
# Epoch 15/150
# 86/86 [==============================] - 15s 169ms/step - loss: 2.2677 - accuracy: 0.4374 - val_loss: 2.4640 - val_accuracy: 0.4075
#
# Epoch 00015: val_accuracy did not improve from 0.47683
# Epoch 16/150
# 86/86 [==============================] - 15s 169ms/step - loss: 2.1982 - accuracy: 0.4498 - val_loss: 2.1053 - val_accuracy: 0.4842
#
# Epoch 00016: val_accuracy improved from 0.47683 to 0.48417, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0016.ckpt
# Epoch 17/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.1492 - accuracy: 0.4585 - val_loss: 2.0179 - val_accuracy: 0.4982
#
# Epoch 00017: val_accuracy improved from 0.48417 to 0.49817, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0017.ckpt
# Epoch 18/150
# 86/86 [==============================] - 15s 169ms/step - loss: 2.0838 - accuracy: 0.4753 - val_loss: 2.0207 - val_accuracy: 0.4988
#
# Epoch 00018: val_accuracy improved from 0.49817 to 0.49883, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0018.ckpt
# Epoch 19/150
# 86/86 [==============================] - 15s 170ms/step - loss: 2.0444 - accuracy: 0.4845 - val_loss: 2.0845 - val_accuracy: 0.4760
#
# Epoch 00019: val_accuracy did not improve from 0.49883
# Epoch 20/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.9773 - accuracy: 0.4962 - val_loss: 1.9203 - val_accuracy: 0.5173
#
# Epoch 00020: val_accuracy improved from 0.49883 to 0.51733, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0020.ckpt
# Epoch 21/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.9410 - accuracy: 0.5079 - val_loss: 1.8344 - val_accuracy: 0.5438
#
# Epoch 00021: val_accuracy improved from 0.51733 to 0.54383, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0021.ckpt
# Epoch 22/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.9095 - accuracy: 0.5128 - val_loss: 1.8154 - val_accuracy: 0.5492
#
# Epoch 00022: val_accuracy improved from 0.54383 to 0.54917, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0022.ckpt
# Epoch 23/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.8714 - accuracy: 0.5257 - val_loss: 1.8455 - val_accuracy: 0.5350
#
# Epoch 00023: val_accuracy did not improve from 0.54917
# Epoch 24/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.8381 - accuracy: 0.5352 - val_loss: 1.7476 - val_accuracy: 0.5557
#
# Epoch 00024: val_accuracy improved from 0.54917 to 0.55567, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0024.ckpt
# Epoch 25/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.8142 - accuracy: 0.5417 - val_loss: 1.7156 - val_accuracy: 0.5658
#
# Epoch 00025: val_accuracy improved from 0.55567 to 0.56583, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0025.ckpt
# Epoch 26/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.7707 - accuracy: 0.5530 - val_loss: 1.6039 - val_accuracy: 0.6037
#
# Epoch 00026: val_accuracy improved from 0.56583 to 0.60367, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0026.ckpt
# Epoch 27/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.7533 - accuracy: 0.5612 - val_loss: 1.6270 - val_accuracy: 0.5997
#
# Epoch 00027: val_accuracy did not improve from 0.60367
# Epoch 28/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.7301 - accuracy: 0.5648 - val_loss: 1.6674 - val_accuracy: 0.5787
#
# Epoch 00028: val_accuracy did not improve from 0.60367
# Epoch 29/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.7038 - accuracy: 0.5723 - val_loss: 1.6116 - val_accuracy: 0.6000
#
# Epoch 00029: val_accuracy did not improve from 0.60367
# Epoch 30/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.6816 - accuracy: 0.5786 - val_loss: 1.5720 - val_accuracy: 0.6122
#
# Epoch 00030: val_accuracy improved from 0.60367 to 0.61217, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0030.ckpt
# Epoch 31/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.6572 - accuracy: 0.5898 - val_loss: 1.6075 - val_accuracy: 0.5978
#
# Epoch 00031: val_accuracy did not improve from 0.61217
# Epoch 32/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.6382 - accuracy: 0.5935 - val_loss: 1.6336 - val_accuracy: 0.5962
#
# Epoch 00032: val_accuracy did not improve from 0.61217
# Epoch 33/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.6110 - accuracy: 0.6046 - val_loss: 1.5511 - val_accuracy: 0.6173
#
# Epoch 00033: val_accuracy improved from 0.61217 to 0.61733, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0033.ckpt
# Epoch 34/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.5897 - accuracy: 0.6085 - val_loss: 1.5491 - val_accuracy: 0.6248
#
# Epoch 00034: val_accuracy improved from 0.61733 to 0.62483, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0034.ckpt
# Epoch 35/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.5651 - accuracy: 0.6136 - val_loss: 1.6321 - val_accuracy: 0.6047
#
# Epoch 00035: val_accuracy did not improve from 0.62483
# Epoch 36/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.5711 - accuracy: 0.6118 - val_loss: 1.4530 - val_accuracy: 0.6567
#
# Epoch 00036: val_accuracy improved from 0.62483 to 0.65667, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0036.ckpt
# Epoch 37/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.5316 - accuracy: 0.6244 - val_loss: 1.6255 - val_accuracy: 0.6058
#
# Epoch 00037: val_accuracy did not improve from 0.65667
# Epoch 38/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.5212 - accuracy: 0.6293 - val_loss: 1.5211 - val_accuracy: 0.6362
#
# Epoch 00038: val_accuracy did not improve from 0.65667
# Epoch 39/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.4962 - accuracy: 0.6368 - val_loss: 1.5232 - val_accuracy: 0.6273
#
# Epoch 00039: val_accuracy did not improve from 0.65667
# Epoch 40/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.4791 - accuracy: 0.6414 - val_loss: 1.5912 - val_accuracy: 0.6147
#
# Epoch 00040: val_accuracy did not improve from 0.65667
# Epoch 41/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.4626 - accuracy: 0.6487 - val_loss: 1.5200 - val_accuracy: 0.6277
#
# Epoch 00041: val_accuracy did not improve from 0.65667
# Epoch 42/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.4591 - accuracy: 0.6515 - val_loss: 1.5125 - val_accuracy: 0.6380
#
# Epoch 00042: val_accuracy did not improve from 0.65667
# Epoch 43/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.4494 - accuracy: 0.6543 - val_loss: 1.4197 - val_accuracy: 0.6697
#
# Epoch 00043: val_accuracy improved from 0.65667 to 0.66967, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0043.ckpt
# Epoch 44/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.4282 - accuracy: 0.6608 - val_loss: 1.4190 - val_accuracy: 0.6603
#
# Epoch 00044: val_accuracy did not improve from 0.66967
# Epoch 45/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.4148 - accuracy: 0.6613 - val_loss: 1.5486 - val_accuracy: 0.6363
#
# Epoch 00045: val_accuracy did not improve from 0.66967
# Epoch 46/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.3963 - accuracy: 0.6707 - val_loss: 1.4292 - val_accuracy: 0.6600
#
# Epoch 00046: val_accuracy did not improve from 0.66967
# Epoch 47/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.3731 - accuracy: 0.6719 - val_loss: 1.5291 - val_accuracy: 0.6388
#
# Epoch 00047: val_accuracy did not improve from 0.66967
# Epoch 48/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.3860 - accuracy: 0.6732 - val_loss: 1.5942 - val_accuracy: 0.6325
#
# Epoch 00048: val_accuracy did not improve from 0.66967
# Epoch 49/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.3605 - accuracy: 0.6809 - val_loss: 1.4736 - val_accuracy: 0.6590
#
# Epoch 00049: val_accuracy did not improve from 0.66967
# Epoch 50/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.3577 - accuracy: 0.6821 - val_loss: 1.3910 - val_accuracy: 0.6765
#
# Epoch 00050: val_accuracy improved from 0.66967 to 0.67650, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0050.ckpt
# Epoch 51/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.3322 - accuracy: 0.6909 - val_loss: 1.3880 - val_accuracy: 0.6822
#
# Epoch 00051: val_accuracy improved from 0.67650 to 0.68217, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0051.ckpt
# Epoch 52/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.3222 - accuracy: 0.6930 - val_loss: 1.4435 - val_accuracy: 0.6713
#
# Epoch 00052: val_accuracy did not improve from 0.68217
# Epoch 53/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.3204 - accuracy: 0.6966 - val_loss: 1.5072 - val_accuracy: 0.6525
#
# Epoch 00053: val_accuracy did not improve from 0.68217
# Epoch 54/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.3079 - accuracy: 0.6983 - val_loss: 1.4184 - val_accuracy: 0.6693
#
# Epoch 00054: val_accuracy did not improve from 0.68217
# Epoch 55/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.2894 - accuracy: 0.7058 - val_loss: 1.3961 - val_accuracy: 0.6698
#
# Epoch 00055: val_accuracy did not improve from 0.68217
# Epoch 56/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2905 - accuracy: 0.7065 - val_loss: 1.3609 - val_accuracy: 0.6927
#
# Epoch 00056: val_accuracy improved from 0.68217 to 0.69267, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0056.ckpt
# Epoch 57/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2625 - accuracy: 0.7153 - val_loss: 1.4380 - val_accuracy: 0.6743
#
# Epoch 00057: val_accuracy did not improve from 0.69267
# Epoch 58/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2555 - accuracy: 0.7203 - val_loss: 1.4019 - val_accuracy: 0.6808
#
# Epoch 00058: val_accuracy did not improve from 0.69267
# Epoch 59/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.2568 - accuracy: 0.7183 - val_loss: 1.4126 - val_accuracy: 0.6763
#
# Epoch 00059: val_accuracy did not improve from 0.69267
# Epoch 60/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2469 - accuracy: 0.7207 - val_loss: 1.4345 - val_accuracy: 0.6742
#
# Epoch 00060: val_accuracy did not improve from 0.69267
# Epoch 61/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2335 - accuracy: 0.7256 - val_loss: 1.5882 - val_accuracy: 0.6343
#
# Epoch 00061: val_accuracy did not improve from 0.69267
# Epoch 62/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2401 - accuracy: 0.7278 - val_loss: 1.5218 - val_accuracy: 0.6588
#
# Epoch 00062: val_accuracy did not improve from 0.69267
# Epoch 63/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.2225 - accuracy: 0.7319 - val_loss: 1.4668 - val_accuracy: 0.6697
#
# Epoch 00063: val_accuracy did not improve from 0.69267
# Epoch 64/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.2190 - accuracy: 0.7324 - val_loss: 1.6180 - val_accuracy: 0.6377
#
# Epoch 00064: val_accuracy did not improve from 0.69267
# Epoch 65/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.2147 - accuracy: 0.7371 - val_loss: 1.3816 - val_accuracy: 0.6933
#
# Epoch 00065: val_accuracy improved from 0.69267 to 0.69333, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0065.ckpt
# Epoch 66/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1902 - accuracy: 0.7419 - val_loss: 1.3786 - val_accuracy: 0.6962
#
# Epoch 00066: val_accuracy improved from 0.69333 to 0.69617, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0066.ckpt
# Epoch 67/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1947 - accuracy: 0.7463 - val_loss: 1.3908 - val_accuracy: 0.6927
#
# Epoch 00067: val_accuracy did not improve from 0.69617
# Epoch 68/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1841 - accuracy: 0.7439 - val_loss: 1.4103 - val_accuracy: 0.6830
#
# Epoch 00068: val_accuracy did not improve from 0.69617
# Epoch 69/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1774 - accuracy: 0.7532 - val_loss: 1.4474 - val_accuracy: 0.6873
#
# Epoch 00069: val_accuracy did not improve from 0.69617
# Epoch 70/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1667 - accuracy: 0.7533 - val_loss: 1.6306 - val_accuracy: 0.6548
#
# Epoch 00070: val_accuracy did not improve from 0.69617
# Epoch 71/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1567 - accuracy: 0.7517 - val_loss: 1.3806 - val_accuracy: 0.7055
#
# Epoch 00071: val_accuracy improved from 0.69617 to 0.70550, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0071.ckpt
# Epoch 72/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1571 - accuracy: 0.7577 - val_loss: 1.4276 - val_accuracy: 0.6895
#
# Epoch 00072: val_accuracy did not improve from 0.70550
# Epoch 73/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1555 - accuracy: 0.7568 - val_loss: 1.4552 - val_accuracy: 0.6900
#
# Epoch 00073: val_accuracy did not improve from 0.70550
# Epoch 74/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1334 - accuracy: 0.7665 - val_loss: 1.3738 - val_accuracy: 0.7127
#
# Epoch 00074: val_accuracy improved from 0.70550 to 0.71267, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0074.ckpt
# Epoch 75/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1314 - accuracy: 0.7658 - val_loss: 1.4153 - val_accuracy: 0.6968
#
# Epoch 00075: val_accuracy did not improve from 0.71267
# Epoch 76/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1223 - accuracy: 0.7707 - val_loss: 1.5126 - val_accuracy: 0.6740
#
# Epoch 00076: val_accuracy did not improve from 0.71267
# Epoch 77/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1235 - accuracy: 0.7694 - val_loss: 1.4037 - val_accuracy: 0.6965
#
# Epoch 00077: val_accuracy did not improve from 0.71267
# Epoch 78/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.1113 - accuracy: 0.7716 - val_loss: 1.5158 - val_accuracy: 0.6807
#
# Epoch 00078: val_accuracy did not improve from 0.71267
# Epoch 79/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1113 - accuracy: 0.7732 - val_loss: 1.3662 - val_accuracy: 0.7020
#
# Epoch 00079: val_accuracy did not improve from 0.71267
# Epoch 80/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.1026 - accuracy: 0.7776 - val_loss: 1.4338 - val_accuracy: 0.6977
#
# Epoch 00080: val_accuracy did not improve from 0.71267
# Epoch 81/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0921 - accuracy: 0.7860 - val_loss: 1.4150 - val_accuracy: 0.7010
#
# Epoch 00081: val_accuracy did not improve from 0.71267
# Epoch 82/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0994 - accuracy: 0.7759 - val_loss: 1.3966 - val_accuracy: 0.7107
#
# Epoch 00082: val_accuracy did not improve from 0.71267
# Epoch 83/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0741 - accuracy: 0.7878 - val_loss: 1.4163 - val_accuracy: 0.7088
#
# Epoch 00083: val_accuracy did not improve from 0.71267
# Epoch 84/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0778 - accuracy: 0.7852 - val_loss: 1.4297 - val_accuracy: 0.7092
#
# Epoch 00084: val_accuracy did not improve from 0.71267
# Epoch 85/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0614 - accuracy: 0.7944 - val_loss: 1.4746 - val_accuracy: 0.6938
#
# Epoch 00085: val_accuracy did not improve from 0.71267
# Epoch 86/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0756 - accuracy: 0.7892 - val_loss: 1.4346 - val_accuracy: 0.7027
#
# Epoch 00086: val_accuracy did not improve from 0.71267
# Epoch 87/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0668 - accuracy: 0.7955 - val_loss: 1.5097 - val_accuracy: 0.6862
#
# Epoch 00087: val_accuracy did not improve from 0.71267
# Epoch 88/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0615 - accuracy: 0.7929 - val_loss: 1.3825 - val_accuracy: 0.7148
#
# Epoch 00088: val_accuracy improved from 0.71267 to 0.71483, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0088.ckpt
# Epoch 89/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0398 - accuracy: 0.7993 - val_loss: 1.3735 - val_accuracy: 0.7118
#
# Epoch 00089: val_accuracy did not improve from 0.71483
# Epoch 90/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0497 - accuracy: 0.7975 - val_loss: 1.4891 - val_accuracy: 0.6997
#
# Epoch 00090: val_accuracy did not improve from 0.71483
# Epoch 91/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0339 - accuracy: 0.8047 - val_loss: 1.3769 - val_accuracy: 0.7242
#
# Epoch 00091: val_accuracy improved from 0.71483 to 0.72417, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0091.ckpt
# Epoch 92/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0319 - accuracy: 0.8054 - val_loss: 1.4988 - val_accuracy: 0.7030
#
# Epoch 00092: val_accuracy did not improve from 0.72417
# Epoch 93/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0301 - accuracy: 0.8102 - val_loss: 1.5162 - val_accuracy: 0.6968
#
# Epoch 00093: val_accuracy did not improve from 0.72417
# Epoch 94/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0288 - accuracy: 0.8074 - val_loss: 1.5255 - val_accuracy: 0.6847
#
# Epoch 00094: val_accuracy did not improve from 0.72417
# Epoch 95/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0195 - accuracy: 0.8109 - val_loss: 1.4435 - val_accuracy: 0.7168
#
# Epoch 00095: val_accuracy did not improve from 0.72417
# Epoch 96/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0171 - accuracy: 0.8115 - val_loss: 1.5870 - val_accuracy: 0.6778
#
# Epoch 00096: val_accuracy did not improve from 0.72417
# Epoch 97/150
# 86/86 [==============================] - 15s 169ms/step - loss: 1.0072 - accuracy: 0.8165 - val_loss: 1.4295 - val_accuracy: 0.7073
#
# Epoch 00097: val_accuracy did not improve from 0.72417
# Epoch 98/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9992 - accuracy: 0.8183 - val_loss: 1.5201 - val_accuracy: 0.7027
#
# Epoch 00098: val_accuracy did not improve from 0.72417
# Epoch 99/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9913 - accuracy: 0.8218 - val_loss: 1.4055 - val_accuracy: 0.7207
#
# Epoch 00099: val_accuracy did not improve from 0.72417
# Epoch 100/150
# 86/86 [==============================] - 15s 170ms/step - loss: 1.0003 - accuracy: 0.8220 - val_loss: 1.4536 - val_accuracy: 0.7188
#
# Epoch 00100: val_accuracy did not improve from 0.72417
# Epoch 101/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9880 - accuracy: 0.8235 - val_loss: 1.3917 - val_accuracy: 0.7210
#
# Epoch 00101: val_accuracy did not improve from 0.72417
# Epoch 102/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9829 - accuracy: 0.8266 - val_loss: 1.5240 - val_accuracy: 0.6985
#
# Epoch 00102: val_accuracy did not improve from 0.72417
# Epoch 103/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9869 - accuracy: 0.8215 - val_loss: 1.4675 - val_accuracy: 0.7162
#
# Epoch 00103: val_accuracy did not improve from 0.72417
# Epoch 104/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9781 - accuracy: 0.8285 - val_loss: 1.4003 - val_accuracy: 0.7273
#
# Epoch 00104: val_accuracy improved from 0.72417 to 0.72733, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0104.ckpt
# Epoch 105/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9759 - accuracy: 0.8300 - val_loss: 1.5154 - val_accuracy: 0.7087
#
# Epoch 00105: val_accuracy did not improve from 0.72733
# Epoch 106/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9699 - accuracy: 0.8332 - val_loss: 1.4322 - val_accuracy: 0.7192
#
# Epoch 00106: val_accuracy did not improve from 0.72733
# Epoch 107/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9721 - accuracy: 0.8324 - val_loss: 1.4884 - val_accuracy: 0.7077
#
# Epoch 00107: val_accuracy did not improve from 0.72733
# Epoch 108/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9727 - accuracy: 0.8319 - val_loss: 1.5048 - val_accuracy: 0.7100
#
# Epoch 00108: val_accuracy did not improve from 0.72733
# Epoch 109/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9553 - accuracy: 0.8412 - val_loss: 1.4475 - val_accuracy: 0.7280
#
# Epoch 00109: val_accuracy improved from 0.72733 to 0.72800, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0109.ckpt
# Epoch 110/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9555 - accuracy: 0.8372 - val_loss: 1.4472 - val_accuracy: 0.7212
#
# Epoch 00110: val_accuracy did not improve from 0.72800
# Epoch 111/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9627 - accuracy: 0.8381 - val_loss: 1.5385 - val_accuracy: 0.7072
#
# Epoch 00111: val_accuracy did not improve from 0.72800
# Epoch 112/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9510 - accuracy: 0.8432 - val_loss: 1.4609 - val_accuracy: 0.7292
#
# Epoch 00112: val_accuracy improved from 0.72800 to 0.72917, saving model to /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0112.ckpt
# Epoch 113/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9609 - accuracy: 0.8398 - val_loss: 1.5563 - val_accuracy: 0.7085
#
# Epoch 00113: val_accuracy did not improve from 0.72917
# Epoch 114/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9468 - accuracy: 0.8423 - val_loss: 1.4685 - val_accuracy: 0.7202
#
# Epoch 00114: val_accuracy did not improve from 0.72917
# Epoch 115/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9427 - accuracy: 0.8448 - val_loss: 1.4361 - val_accuracy: 0.7238
#
# Epoch 00115: val_accuracy did not improve from 0.72917
# Epoch 116/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9408 - accuracy: 0.8472 - val_loss: 1.4675 - val_accuracy: 0.7198
#
# Epoch 00116: val_accuracy did not improve from 0.72917
# Epoch 117/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9336 - accuracy: 0.8487 - val_loss: 1.6637 - val_accuracy: 0.6878
#
# Epoch 00117: val_accuracy did not improve from 0.72917
# Epoch 118/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9343 - accuracy: 0.8494 - val_loss: 1.6191 - val_accuracy: 0.7042
#
# Epoch 00118: val_accuracy did not improve from 0.72917
# Epoch 119/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9523 - accuracy: 0.8432 - val_loss: 1.4965 - val_accuracy: 0.7120
#
# Epoch 00119: val_accuracy did not improve from 0.72917
# Epoch 120/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9267 - accuracy: 0.8513 - val_loss: 1.4704 - val_accuracy: 0.7283
#
# Epoch 00120: val_accuracy did not improve from 0.72917
# Epoch 121/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9106 - accuracy: 0.8565 - val_loss: 1.4841 - val_accuracy: 0.7237
#
# Epoch 00121: val_accuracy did not improve from 0.72917
# Epoch 122/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9205 - accuracy: 0.8545 - val_loss: 1.6545 - val_accuracy: 0.6978
#
# Epoch 00122: val_accuracy did not improve from 0.72917
# Epoch 123/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.9209 - accuracy: 0.8534 - val_loss: 1.4653 - val_accuracy: 0.7268
#
# Epoch 00123: val_accuracy did not improve from 0.72917
# Epoch 124/150
# 86/86 [==============================] - 15s 170ms/step - loss: 0.8956 - accuracy: 0.8615 - val_loss: 1.5092 - val_accuracy: 0.7177
#
# Epoch 00124: val_accuracy did not improve from 0.72917
# Epoch 125/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9099 - accuracy: 0.8575 - val_loss: 1.4921 - val_accuracy: 0.7275
#
# Epoch 00125: val_accuracy did not improve from 0.72917
# Epoch 126/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9109 - accuracy: 0.8587 - val_loss: 1.4518 - val_accuracy: 0.7277
#
# Epoch 00126: val_accuracy did not improve from 0.72917
# Epoch 127/150
# 86/86 [==============================] - 15s 169ms/step - loss: 0.9060 - accuracy: 0.8607 - val_loss: 1.5752 - val_accuracy: 0.7082
#
# Epoch 00127: val_accuracy did not improve from 0.72917
# Training set Accuracy: 0.9393
# Training set Loss: 0.6664
#
# Validation set Accuracy: 0.7082
# Validation set Loss: 1.5752

# %% [markdown]
# ###10. Reconstructing the best performing model encountered during training (based on validation score)

# %%
#Reconstruct the best model encountered during training. This was saved by the ModelCheckpoint. 
#Since we told it to 'save_best_only', it has saved model weights each time an improvement occurred. 
#Our best model is therefore the last of the saved checkpoints.
import pathlib

# Find latest checkpoint
# Sort the checkpoints by modification time.
checkpoints = pathlib.Path(checkpoint_dir).glob("*.index")
checkpoints = sorted(checkpoints, key=lambda cp:cp.stat().st_mtime)
checkpoints = [cp.with_suffix('') for cp in checkpoints]
latest = str(checkpoints[-1])
print(latest)
checkpoints
# Out:
# /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0112.ckpt
# [PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0004.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0019.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0027.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0035.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0037.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0038.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0039.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0041.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0042.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0045.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0053.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0059.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0063.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0001.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0002.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0003.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0005.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0006.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0007.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0008.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0009.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0010.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0011.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0013.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0016.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0017.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0018.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0020.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0021.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0022.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0024.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0025.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0026.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0030.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0033.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0034.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0036.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0043.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0050.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0051.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0056.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0065.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0066.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0071.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0074.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0088.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0091.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0104.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0109.ckpt'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/cp-0112.ckpt')]

# %%
# Now restore the model
best_model_1 = initial_model() # this is a new model
best_model_1.load_weights(latest)

# The code below should give slightly better results than that for the original model
[train_loss, train_accuracy] = best_model_1.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.4f}".format(train_accuracy))
print("Training set Loss:{:7.6f}\n".format(train_loss))

[val_loss, val_accuracy] = best_model_1.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.4f}".format(val_accuracy))
print("Validation set Loss:{:7.6f}\n".format(val_loss))
# Out:
# Training set Accuracy: 0.9381
# Training set Loss:0.653056
#
# Validation set Accuracy: 0.7292
# Validation set Loss:1.460938

# %% [markdown]
# ###11. Data augmentation (with train and validation set)

# %%
batch_size = 512
epochs = 150

au_model = initial_model()
au_model.summary()
au_model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# dummy file path here ... this is local on Colab!
filepath = 'au_model.h5'

callbacks = [EarlyStopping(monitor='val_accuracy', patience=15, min_delta=0.0001),
             ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True)]

datagen = ImageDataGenerator(
        # rotation_range=15.0,  # randomly rotate images in the range (degrees, 0 to 180) - note that rotation is more compute-intensive than shifting!!
        # width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        # height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        # vertical_flip=False,  # randomly flip images
        fill_mode = 'nearest', # what to do with 'new' pixels that occur as the result of a transformation
        # zoom_range = 0.2)  
        #shear_range = 15
)

# Compute quantities required for some augmentation functions
# (e.g., std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train, augment=True)

# Fit the model on the batches generated by datagen.flow().
au_history = au_model.fit(datagen.flow(x_train, r_train, batch_size=batch_size),
                                    epochs=epochs, steps_per_epoch=len(x_train) / batch_size,
                                    validation_data=(x_val, r_val),
                                    callbacks = callbacks)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_54 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_72 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_73 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_74 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_75 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 8, 8, 512)         590336
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_76 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_77 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# activation_78 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                10260
# _________________________________________________________________
# activation_79 (Activation)   (None, 20)                0
# =================================================================
# Total params: 7,421,012
# Trainable params: 7,418,196
# Non-trainable params: 2,816
# _________________________________________________________________
# Epoch 1/150
# 85/85 [==============================] - 17s 178ms/step - loss: 5.6312 - accuracy: 0.0630 - val_loss: 4.3941 - val_accuracy: 0.0492
#
# Epoch 00001: val_accuracy improved from -inf to 0.04917, saving model to au_model.h5
# Epoch 2/150
# 85/85 [==============================] - 15s 178ms/step - loss: 4.1859 - accuracy: 0.0807 - val_loss: 3.9904 - val_accuracy: 0.0545
#
# Epoch 00002: val_accuracy improved from 0.04917 to 0.05450, saving model to au_model.h5
# Epoch 3/150
# 85/85 [==============================] - 15s 177ms/step - loss: 3.7231 - accuracy: 0.0954 - val_loss: 3.6765 - val_accuracy: 0.0543
#
# Epoch 00003: val_accuracy did not improve from 0.05450
# Epoch 4/150
# 85/85 [==============================] - 15s 175ms/step - loss: 3.4042 - accuracy: 0.0976 - val_loss: 3.4780 - val_accuracy: 0.0493
#
# Epoch 00004: val_accuracy did not improve from 0.05450
# Epoch 5/150
# 85/85 [==============================] - 15s 174ms/step - loss: 3.1989 - accuracy: 0.1039 - val_loss: 3.3049 - val_accuracy: 0.0592
#
# Epoch 00005: val_accuracy improved from 0.05450 to 0.05917, saving model to au_model.h5
# Epoch 6/150
# 85/85 [==============================] - 15s 176ms/step - loss: 3.0610 - accuracy: 0.1121 - val_loss: 3.1184 - val_accuracy: 0.0863
#
# Epoch 00006: val_accuracy improved from 0.05917 to 0.08633, saving model to au_model.h5
# Epoch 7/150
# 85/85 [==============================] - 15s 177ms/step - loss: 2.9670 - accuracy: 0.1246 - val_loss: 2.9306 - val_accuracy: 0.1612
#
# Epoch 00007: val_accuracy improved from 0.08633 to 0.16117, saving model to au_model.h5
# Epoch 8/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.8840 - accuracy: 0.1380 - val_loss: 2.7415 - val_accuracy: 0.1820
#
# Epoch 00008: val_accuracy improved from 0.16117 to 0.18200, saving model to au_model.h5
# Epoch 9/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.8103 - accuracy: 0.1500 - val_loss: 2.7510 - val_accuracy: 0.1887
#
# Epoch 00009: val_accuracy improved from 0.18200 to 0.18867, saving model to au_model.h5
# Epoch 10/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.7226 - accuracy: 0.1807 - val_loss: 2.6111 - val_accuracy: 0.2533
#
# Epoch 00010: val_accuracy improved from 0.18867 to 0.25333, saving model to au_model.h5
# Epoch 11/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.6414 - accuracy: 0.2021 - val_loss: 2.8852 - val_accuracy: 0.1788
#
# Epoch 00011: val_accuracy did not improve from 0.25333
# Epoch 12/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.5872 - accuracy: 0.2257 - val_loss: 2.5295 - val_accuracy: 0.2640
#
# Epoch 00012: val_accuracy improved from 0.25333 to 0.26400, saving model to au_model.h5
# Epoch 13/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.5179 - accuracy: 0.2559 - val_loss: 2.5320 - val_accuracy: 0.2787
#
# Epoch 00013: val_accuracy improved from 0.26400 to 0.27867, saving model to au_model.h5
# Epoch 14/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.4449 - accuracy: 0.2811 - val_loss: 2.4993 - val_accuracy: 0.3007
#
# Epoch 00014: val_accuracy improved from 0.27867 to 0.30067, saving model to au_model.h5
# Epoch 15/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.3747 - accuracy: 0.3064 - val_loss: 2.8146 - val_accuracy: 0.2233
#
# Epoch 00015: val_accuracy did not improve from 0.30067
# Epoch 16/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.3191 - accuracy: 0.3354 - val_loss: 2.3226 - val_accuracy: 0.3388
#
# Epoch 00016: val_accuracy improved from 0.30067 to 0.33883, saving model to au_model.h5
# Epoch 17/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.2845 - accuracy: 0.3508 - val_loss: 2.0941 - val_accuracy: 0.4173
#
# Epoch 00017: val_accuracy improved from 0.33883 to 0.41733, saving model to au_model.h5
# Epoch 18/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.2363 - accuracy: 0.3765 - val_loss: 2.4105 - val_accuracy: 0.3498
#
# Epoch 00018: val_accuracy did not improve from 0.41733
# Epoch 19/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.1908 - accuracy: 0.3924 - val_loss: 2.7679 - val_accuracy: 0.3052
#
# Epoch 00019: val_accuracy did not improve from 0.41733
# Epoch 20/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.1481 - accuracy: 0.4103 - val_loss: 2.3428 - val_accuracy: 0.3593
#
# Epoch 00020: val_accuracy did not improve from 0.41733
# Epoch 21/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.1084 - accuracy: 0.4285 - val_loss: 2.1035 - val_accuracy: 0.4518
#
# Epoch 00021: val_accuracy improved from 0.41733 to 0.45183, saving model to au_model.h5
# Epoch 22/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.0639 - accuracy: 0.4469 - val_loss: 2.0180 - val_accuracy: 0.4548
#
# Epoch 00022: val_accuracy improved from 0.45183 to 0.45483, saving model to au_model.h5
# Epoch 23/150
# 85/85 [==============================] - 15s 176ms/step - loss: 2.0269 - accuracy: 0.4677 - val_loss: 2.2160 - val_accuracy: 0.4247
#
# Epoch 00023: val_accuracy did not improve from 0.45483
# Epoch 24/150
# 85/85 [==============================] - 15s 175ms/step - loss: 2.0459 - accuracy: 0.4696 - val_loss: 2.0628 - val_accuracy: 0.4663
#
# Epoch 00024: val_accuracy improved from 0.45483 to 0.46633, saving model to au_model.h5
# Epoch 25/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.9835 - accuracy: 0.4900 - val_loss: 1.9690 - val_accuracy: 0.4847
#
# Epoch 00025: val_accuracy improved from 0.46633 to 0.48467, saving model to au_model.h5
# Epoch 26/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.9595 - accuracy: 0.5002 - val_loss: 2.0346 - val_accuracy: 0.4967
#
# Epoch 00026: val_accuracy improved from 0.48467 to 0.49667, saving model to au_model.h5
# Epoch 27/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.9411 - accuracy: 0.5155 - val_loss: 2.1506 - val_accuracy: 0.4567
#
# Epoch 00027: val_accuracy did not improve from 0.49667
# Epoch 28/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.9017 - accuracy: 0.5253 - val_loss: 1.9803 - val_accuracy: 0.5065
#
# Epoch 00028: val_accuracy improved from 0.49667 to 0.50650, saving model to au_model.h5
# Epoch 29/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8981 - accuracy: 0.5348 - val_loss: 1.9307 - val_accuracy: 0.5208
#
# Epoch 00029: val_accuracy improved from 0.50650 to 0.52083, saving model to au_model.h5
# Epoch 30/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8798 - accuracy: 0.5421 - val_loss: 2.0612 - val_accuracy: 0.4835
#
# Epoch 00030: val_accuracy did not improve from 0.52083
# Epoch 31/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8642 - accuracy: 0.5458 - val_loss: 2.2011 - val_accuracy: 0.4693
#
# Epoch 00031: val_accuracy did not improve from 0.52083
# Epoch 32/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8408 - accuracy: 0.5592 - val_loss: 1.8869 - val_accuracy: 0.5498
#
# Epoch 00032: val_accuracy improved from 0.52083 to 0.54983, saving model to au_model.h5
# Epoch 33/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8335 - accuracy: 0.5604 - val_loss: 1.8708 - val_accuracy: 0.5553
#
# Epoch 00033: val_accuracy improved from 0.54983 to 0.55533, saving model to au_model.h5
# Epoch 34/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8171 - accuracy: 0.5711 - val_loss: 2.0849 - val_accuracy: 0.5088
#
# Epoch 00034: val_accuracy did not improve from 0.55533
# Epoch 35/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.8109 - accuracy: 0.5748 - val_loss: 1.9678 - val_accuracy: 0.5375
#
# Epoch 00035: val_accuracy did not improve from 0.55533
# Epoch 36/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7837 - accuracy: 0.5874 - val_loss: 2.0451 - val_accuracy: 0.5300
#
# Epoch 00036: val_accuracy did not improve from 0.55533
# Epoch 37/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7794 - accuracy: 0.5898 - val_loss: 1.7962 - val_accuracy: 0.5773
#
# Epoch 00037: val_accuracy improved from 0.55533 to 0.57733, saving model to au_model.h5
# Epoch 38/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.7509 - accuracy: 0.6049 - val_loss: 1.9180 - val_accuracy: 0.5500
#
# Epoch 00038: val_accuracy did not improve from 0.57733
# Epoch 39/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7586 - accuracy: 0.6039 - val_loss: 2.5866 - val_accuracy: 0.4553
#
# Epoch 00039: val_accuracy did not improve from 0.57733
# Epoch 40/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.7290 - accuracy: 0.6130 - val_loss: 1.9294 - val_accuracy: 0.5528
#
# Epoch 00040: val_accuracy did not improve from 0.57733
# Epoch 41/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7171 - accuracy: 0.6200 - val_loss: 1.7298 - val_accuracy: 0.6110
#
# Epoch 00041: val_accuracy improved from 0.57733 to 0.61100, saving model to au_model.h5
# Epoch 42/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7320 - accuracy: 0.6140 - val_loss: 2.0668 - val_accuracy: 0.5282
#
# Epoch 00042: val_accuracy did not improve from 0.61100
# Epoch 43/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.7161 - accuracy: 0.6247 - val_loss: 2.0582 - val_accuracy: 0.5495
#
# Epoch 00043: val_accuracy did not improve from 0.61100
# Epoch 44/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.6997 - accuracy: 0.6334 - val_loss: 2.2026 - val_accuracy: 0.5067
#
# Epoch 00044: val_accuracy did not improve from 0.61100
# Epoch 45/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.6967 - accuracy: 0.6343 - val_loss: 2.2081 - val_accuracy: 0.5213
#
# Epoch 00045: val_accuracy did not improve from 0.61100
# Epoch 46/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6880 - accuracy: 0.6371 - val_loss: 1.7491 - val_accuracy: 0.6237
#
# Epoch 00046: val_accuracy improved from 0.61100 to 0.62367, saving model to au_model.h5
# Epoch 47/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6805 - accuracy: 0.6441 - val_loss: 1.7105 - val_accuracy: 0.6327
#
# Epoch 00047: val_accuracy improved from 0.62367 to 0.63267, saving model to au_model.h5
# Epoch 48/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.6451 - accuracy: 0.6572 - val_loss: 1.7971 - val_accuracy: 0.6042
#
# Epoch 00048: val_accuracy did not improve from 0.63267
# Epoch 49/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6543 - accuracy: 0.6579 - val_loss: 1.9536 - val_accuracy: 0.5760
#
# Epoch 00049: val_accuracy did not improve from 0.63267
# Epoch 50/150
# 85/85 [==============================] - 15s 176ms/step - loss: 1.6418 - accuracy: 0.6637 - val_loss: 1.8313 - val_accuracy: 0.6055
#
# Epoch 00050: val_accuracy did not improve from 0.63267
# Epoch 51/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6469 - accuracy: 0.6601 - val_loss: 1.8049 - val_accuracy: 0.6115
#
# Epoch 00051: val_accuracy did not improve from 0.63267
# Epoch 52/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6180 - accuracy: 0.6711 - val_loss: 1.7083 - val_accuracy: 0.6412
#
# Epoch 00052: val_accuracy improved from 0.63267 to 0.64117, saving model to au_model.h5
# Epoch 53/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6259 - accuracy: 0.6735 - val_loss: 2.2396 - val_accuracy: 0.5467
#
# Epoch 00053: val_accuracy did not improve from 0.64117
# Epoch 54/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6172 - accuracy: 0.6736 - val_loss: 1.7691 - val_accuracy: 0.6252
#
# Epoch 00054: val_accuracy did not improve from 0.64117
# Epoch 55/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5972 - accuracy: 0.6816 - val_loss: 1.9439 - val_accuracy: 0.5860
#
# Epoch 00055: val_accuracy did not improve from 0.64117
# Epoch 56/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6097 - accuracy: 0.6791 - val_loss: 1.9565 - val_accuracy: 0.5720
#
# Epoch 00056: val_accuracy did not improve from 0.64117
# Epoch 57/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6198 - accuracy: 0.6770 - val_loss: 1.9965 - val_accuracy: 0.5887
#
# Epoch 00057: val_accuracy did not improve from 0.64117
# Epoch 58/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.6178 - accuracy: 0.6817 - val_loss: 1.7218 - val_accuracy: 0.6375
#
# Epoch 00058: val_accuracy did not improve from 0.64117
# Epoch 59/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5939 - accuracy: 0.6881 - val_loss: 1.8115 - val_accuracy: 0.6258
#
# Epoch 00059: val_accuracy did not improve from 0.64117
# Epoch 60/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5870 - accuracy: 0.6928 - val_loss: 1.6861 - val_accuracy: 0.6565
#
# Epoch 00060: val_accuracy improved from 0.64117 to 0.65650, saving model to au_model.h5
# Epoch 61/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5776 - accuracy: 0.6928 - val_loss: 1.9690 - val_accuracy: 0.5773
#
# Epoch 00061: val_accuracy did not improve from 0.65650
# Epoch 62/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5695 - accuracy: 0.6986 - val_loss: 2.0226 - val_accuracy: 0.5815
#
# Epoch 00062: val_accuracy did not improve from 0.65650
# Epoch 63/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5660 - accuracy: 0.6959 - val_loss: 1.9244 - val_accuracy: 0.6092
#
# Epoch 00063: val_accuracy did not improve from 0.65650
# Epoch 64/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5600 - accuracy: 0.7034 - val_loss: 1.8285 - val_accuracy: 0.6347
#
# Epoch 00064: val_accuracy did not improve from 0.65650
# Epoch 65/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5599 - accuracy: 0.7049 - val_loss: 1.8314 - val_accuracy: 0.6242
#
# Epoch 00065: val_accuracy did not improve from 0.65650
# Epoch 66/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5604 - accuracy: 0.7070 - val_loss: 1.7303 - val_accuracy: 0.6615
#
# Epoch 00066: val_accuracy improved from 0.65650 to 0.66150, saving model to au_model.h5
# Epoch 67/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5577 - accuracy: 0.7092 - val_loss: 1.8522 - val_accuracy: 0.6277
#
# Epoch 00067: val_accuracy did not improve from 0.66150
# Epoch 68/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5577 - accuracy: 0.7093 - val_loss: 1.7746 - val_accuracy: 0.6465
#
# Epoch 00068: val_accuracy did not improve from 0.66150
# Epoch 69/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5499 - accuracy: 0.7118 - val_loss: 1.6674 - val_accuracy: 0.6795
#
# Epoch 00069: val_accuracy improved from 0.66150 to 0.67950, saving model to au_model.h5
# Epoch 70/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5339 - accuracy: 0.7179 - val_loss: 1.7788 - val_accuracy: 0.6392
#
# Epoch 00070: val_accuracy did not improve from 0.67950
# Epoch 71/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5445 - accuracy: 0.7165 - val_loss: 1.9047 - val_accuracy: 0.6198
#
# Epoch 00071: val_accuracy did not improve from 0.67950
# Epoch 72/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5494 - accuracy: 0.7143 - val_loss: 1.8554 - val_accuracy: 0.6397
#
# Epoch 00072: val_accuracy did not improve from 0.67950
# Epoch 73/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5331 - accuracy: 0.7213 - val_loss: 1.7982 - val_accuracy: 0.6443
#
# Epoch 00073: val_accuracy did not improve from 0.67950
# Epoch 74/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5453 - accuracy: 0.7215 - val_loss: 1.6659 - val_accuracy: 0.6887
#
# Epoch 00074: val_accuracy improved from 0.67950 to 0.68867, saving model to au_model.h5
# Epoch 75/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5287 - accuracy: 0.7255 - val_loss: 1.9522 - val_accuracy: 0.6082
#
# Epoch 00075: val_accuracy did not improve from 0.68867
# Epoch 76/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5173 - accuracy: 0.7292 - val_loss: 1.7730 - val_accuracy: 0.6538
#
# Epoch 00076: val_accuracy did not improve from 0.68867
# Epoch 77/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5425 - accuracy: 0.7223 - val_loss: 1.8788 - val_accuracy: 0.6255
#
# Epoch 00077: val_accuracy did not improve from 0.68867
# Epoch 78/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5232 - accuracy: 0.7339 - val_loss: 1.7878 - val_accuracy: 0.6577
#
# Epoch 00078: val_accuracy did not improve from 0.68867
# Epoch 79/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5275 - accuracy: 0.7273 - val_loss: 1.9821 - val_accuracy: 0.6170
#
# Epoch 00079: val_accuracy did not improve from 0.68867
# Epoch 80/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5230 - accuracy: 0.7263 - val_loss: 1.7151 - val_accuracy: 0.6717
#
# Epoch 00080: val_accuracy did not improve from 0.68867
# Epoch 81/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5077 - accuracy: 0.7345 - val_loss: 1.6895 - val_accuracy: 0.6802
#
# Epoch 00081: val_accuracy did not improve from 0.68867
# Epoch 82/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5138 - accuracy: 0.7339 - val_loss: 1.7261 - val_accuracy: 0.6703
#
# Epoch 00082: val_accuracy did not improve from 0.68867
# Epoch 83/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5004 - accuracy: 0.7383 - val_loss: 1.8108 - val_accuracy: 0.6552
#
# Epoch 00083: val_accuracy did not improve from 0.68867
# Epoch 84/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5228 - accuracy: 0.7334 - val_loss: 1.8014 - val_accuracy: 0.6635
#
# Epoch 00084: val_accuracy did not improve from 0.68867
# Epoch 85/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.5207 - accuracy: 0.7348 - val_loss: 1.6645 - val_accuracy: 0.6913
#
# Epoch 00085: val_accuracy improved from 0.68867 to 0.69133, saving model to au_model.h5
# Epoch 86/150
# 85/85 [==============================] - 15s 175ms/step - loss: 1.5039 - accuracy: 0.7371 - val_loss: 1.6828 - val_accuracy: 0.6835
#
# Epoch 00086: val_accuracy did not improve from 0.69133
# Epoch 87/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4996 - accuracy: 0.7383 - val_loss: 1.7820 - val_accuracy: 0.6508
#
# Epoch 00087: val_accuracy did not improve from 0.69133
# Epoch 88/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5023 - accuracy: 0.7380 - val_loss: 1.9631 - val_accuracy: 0.6373
#
# Epoch 00088: val_accuracy did not improve from 0.69133
# Epoch 89/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4930 - accuracy: 0.7442 - val_loss: 1.9681 - val_accuracy: 0.6108
#
# Epoch 00089: val_accuracy did not improve from 0.69133
# Epoch 90/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4895 - accuracy: 0.7468 - val_loss: 1.7102 - val_accuracy: 0.6723
#
# Epoch 00090: val_accuracy did not improve from 0.69133
# Epoch 91/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4991 - accuracy: 0.7454 - val_loss: 1.8146 - val_accuracy: 0.6542
#
# Epoch 00091: val_accuracy did not improve from 0.69133
# Epoch 92/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5094 - accuracy: 0.7438 - val_loss: 1.9790 - val_accuracy: 0.6207
#
# Epoch 00092: val_accuracy did not improve from 0.69133
# Epoch 93/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4902 - accuracy: 0.7461 - val_loss: 1.6857 - val_accuracy: 0.6898
#
# Epoch 00093: val_accuracy did not improve from 0.69133
# Epoch 94/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.5070 - accuracy: 0.7435 - val_loss: 1.6981 - val_accuracy: 0.6928
#
# Epoch 00094: val_accuracy improved from 0.69133 to 0.69283, saving model to au_model.h5
# Epoch 95/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4869 - accuracy: 0.7512 - val_loss: 1.6281 - val_accuracy: 0.6998
#
# Epoch 00095: val_accuracy improved from 0.69283 to 0.69983, saving model to au_model.h5
# Epoch 96/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4914 - accuracy: 0.7504 - val_loss: 1.6722 - val_accuracy: 0.6915
#
# Epoch 00096: val_accuracy did not improve from 0.69983
# Epoch 97/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.5026 - accuracy: 0.7450 - val_loss: 1.6577 - val_accuracy: 0.6860
#
# Epoch 00097: val_accuracy did not improve from 0.69983
# Epoch 98/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4963 - accuracy: 0.7504 - val_loss: 1.8239 - val_accuracy: 0.6773
#
# Epoch 00098: val_accuracy did not improve from 0.69983
# Epoch 99/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4902 - accuracy: 0.7499 - val_loss: 1.7265 - val_accuracy: 0.6807
#
# Epoch 00099: val_accuracy did not improve from 0.69983
# Epoch 100/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4927 - accuracy: 0.7487 - val_loss: 1.8682 - val_accuracy: 0.6458
#
# Epoch 00100: val_accuracy did not improve from 0.69983
# Epoch 101/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4745 - accuracy: 0.7596 - val_loss: 1.8085 - val_accuracy: 0.6568
#
# Epoch 00101: val_accuracy did not improve from 0.69983
# Epoch 102/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4988 - accuracy: 0.7524 - val_loss: 2.0546 - val_accuracy: 0.6350
#
# Epoch 00102: val_accuracy did not improve from 0.69983
# Epoch 103/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4912 - accuracy: 0.7551 - val_loss: 1.8050 - val_accuracy: 0.6862
#
# Epoch 00103: val_accuracy did not improve from 0.69983
# Epoch 104/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4825 - accuracy: 0.7552 - val_loss: 1.9488 - val_accuracy: 0.6460
#
# Epoch 00104: val_accuracy did not improve from 0.69983
# Epoch 105/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4948 - accuracy: 0.7539 - val_loss: 1.8398 - val_accuracy: 0.6797
#
# Epoch 00105: val_accuracy did not improve from 0.69983
# Epoch 106/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4970 - accuracy: 0.7510 - val_loss: 1.6549 - val_accuracy: 0.7125
#
# Epoch 00106: val_accuracy improved from 0.69983 to 0.71250, saving model to au_model.h5
# Epoch 107/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4925 - accuracy: 0.7595 - val_loss: 1.9512 - val_accuracy: 0.6343
#
# Epoch 00107: val_accuracy did not improve from 0.71250
# Epoch 108/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4932 - accuracy: 0.7583 - val_loss: 1.7375 - val_accuracy: 0.6957
#
# Epoch 00108: val_accuracy did not improve from 0.71250
# Epoch 109/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4880 - accuracy: 0.7579 - val_loss: 1.8184 - val_accuracy: 0.6703
#
# Epoch 00109: val_accuracy did not improve from 0.71250
# Epoch 110/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4786 - accuracy: 0.7638 - val_loss: 1.7616 - val_accuracy: 0.6900
#
# Epoch 00110: val_accuracy did not improve from 0.71250
# Epoch 111/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4898 - accuracy: 0.7608 - val_loss: 1.8371 - val_accuracy: 0.6668
#
# Epoch 00111: val_accuracy did not improve from 0.71250
# Epoch 112/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4811 - accuracy: 0.7634 - val_loss: 1.8260 - val_accuracy: 0.6680
#
# Epoch 00112: val_accuracy did not improve from 0.71250
# Epoch 113/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4812 - accuracy: 0.7631 - val_loss: 1.8747 - val_accuracy: 0.6547
#
# Epoch 00113: val_accuracy did not improve from 0.71250
# Epoch 114/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4765 - accuracy: 0.7638 - val_loss: 1.7325 - val_accuracy: 0.6895
#
# Epoch 00114: val_accuracy did not improve from 0.71250
# Epoch 115/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4802 - accuracy: 0.7613 - val_loss: 1.6561 - val_accuracy: 0.7118
#
# Epoch 00115: val_accuracy did not improve from 0.71250
# Epoch 116/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4845 - accuracy: 0.7644 - val_loss: 1.9613 - val_accuracy: 0.6427
#
# Epoch 00116: val_accuracy did not improve from 0.71250
# Epoch 117/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4892 - accuracy: 0.7675 - val_loss: 1.8026 - val_accuracy: 0.6832
#
# Epoch 00117: val_accuracy did not improve from 0.71250
# Epoch 118/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4979 - accuracy: 0.7626 - val_loss: 1.8898 - val_accuracy: 0.6682
#
# Epoch 00118: val_accuracy did not improve from 0.71250
# Epoch 119/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4740 - accuracy: 0.7685 - val_loss: 1.9013 - val_accuracy: 0.6633
#
# Epoch 00119: val_accuracy did not improve from 0.71250
# Epoch 120/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4902 - accuracy: 0.7681 - val_loss: 1.7978 - val_accuracy: 0.6900
#
# Epoch 00120: val_accuracy did not improve from 0.71250
# Epoch 121/150
# 85/85 [==============================] - 15s 172ms/step - loss: 1.4698 - accuracy: 0.7677 - val_loss: 1.6374 - val_accuracy: 0.7185
#
# Epoch 00121: val_accuracy improved from 0.71250 to 0.71850, saving model to au_model.h5
# Epoch 122/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4806 - accuracy: 0.7665 - val_loss: 1.7616 - val_accuracy: 0.6862
#
# Epoch 00122: val_accuracy did not improve from 0.71850
# Epoch 123/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4905 - accuracy: 0.7659 - val_loss: 1.7773 - val_accuracy: 0.6890
#
# Epoch 00123: val_accuracy did not improve from 0.71850
# Epoch 124/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4880 - accuracy: 0.7679 - val_loss: 1.7816 - val_accuracy: 0.6843
#
# Epoch 00124: val_accuracy did not improve from 0.71850
# Epoch 125/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4731 - accuracy: 0.7680 - val_loss: 1.7985 - val_accuracy: 0.6790
#
# Epoch 00125: val_accuracy did not improve from 0.71850
# Epoch 126/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4667 - accuracy: 0.7736 - val_loss: 1.8064 - val_accuracy: 0.6727
#
# Epoch 00126: val_accuracy did not improve from 0.71850
# Epoch 127/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4834 - accuracy: 0.7676 - val_loss: 1.8189 - val_accuracy: 0.6800
#
# Epoch 00127: val_accuracy did not improve from 0.71850
# Epoch 128/150
# 85/85 [==============================] - 15s 173ms/step - loss: 1.4819 - accuracy: 0.7694 - val_loss: 1.8381 - val_accuracy: 0.6855
#
# Epoch 00128: val_accuracy did not improve from 0.71850
# Epoch 129/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4618 - accuracy: 0.7762 - val_loss: 1.7677 - val_accuracy: 0.6915
#
# Epoch 00129: val_accuracy did not improve from 0.71850
# Epoch 130/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4827 - accuracy: 0.7693 - val_loss: 1.9158 - val_accuracy: 0.6617
#
# Epoch 00130: val_accuracy did not improve from 0.71850
# Epoch 131/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4831 - accuracy: 0.7705 - val_loss: 1.7040 - val_accuracy: 0.7025
#
# Epoch 00131: val_accuracy did not improve from 0.71850
# Epoch 132/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4891 - accuracy: 0.7695 - val_loss: 1.8970 - val_accuracy: 0.6690
#
# Epoch 00132: val_accuracy did not improve from 0.71850
# Epoch 133/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4914 - accuracy: 0.7680 - val_loss: 1.8489 - val_accuracy: 0.6755
#
# Epoch 00133: val_accuracy did not improve from 0.71850
# Epoch 134/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4716 - accuracy: 0.7767 - val_loss: 1.8189 - val_accuracy: 0.6945
#
# Epoch 00134: val_accuracy did not improve from 0.71850
# Epoch 135/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4808 - accuracy: 0.7756 - val_loss: 1.8103 - val_accuracy: 0.6872
#
# Epoch 00135: val_accuracy did not improve from 0.71850
# Epoch 136/150
# 85/85 [==============================] - 15s 174ms/step - loss: 1.4737 - accuracy: 0.7790 - val_loss: 1.7689 - val_accuracy: 0.7040
#
# Epoch 00136: val_accuracy did not improve from 0.71850

# %%
[train_loss, train_accuracy] = au_model.evaluate(x_train, r_train, verbose=0)
print("Training set Accuracy:{:7.2f}".format(train_accuracy))
print("Training set Loss:{:7.4f}\n".format(train_loss))

[val_loss, val_accuracy] = au_model.evaluate(x_val, r_val, verbose=0)
print("Validation set Accuracy:{:7.2f}".format(val_accuracy))
print("Validation set Loss:{:7.4f}\n".format(val_loss))
# Out:
# Training set Accuracy:   0.78
# Training set Loss: 1.4303
#
# Validation set Accuracy:   0.70
# Validation set Loss: 1.7689

# %%
def plot_dual_history(before,after):
  plt.figure(figsize = (20,6))
  plt.subplot(1,2,1)

  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(before.epoch, np.array(before.history['accuracy']),'g-',
           label='Initial train accuracy')
  plt.plot(after.epoch, np.array(after.history['accuracy']),'g:',
           label='Final train accuracy')
  plt.plot(before.epoch, np.array(before.history['val_accuracy']),'r-',
           label = 'Initial validation accuracy')
  plt.plot(after.epoch, np.array(after.history['val_accuracy']),'r:',
           label = 'Final validation accuracy')
  plt.ylim([0.0,1.0])
  plt.legend()

  plt.subplot(1,2,2)
  plt.xlabel('Epoch')
  plt.ylabel('Loss minimised by model')
  plt.plot(before.epoch, np.array(before.history['loss']),'g-',
           label='Initial train loss')
  plt.plot(after.epoch, np.array(after.history['loss']),'g:',
           label='Final train loss')
  plt.plot(before.epoch, np.array(before.history['val_loss']),'r-',
           label = 'Initial validation loss')
  plt.plot(after.epoch, np.array(after.history['val_loss']),'r:',
           label = 'Final validation loss')
  plt.legend()

plot_dual_history(history_1, au_history)

# %% [markdown]
# ###12. Final model training on full training data (without augmentation)
# Here, we re-train it on the full original training set (i.e., including the validation set) and use the number of EPOCHS that corresponds to our best validation score in the previous run (which is 112). Once this re-training has been done, we analyse how our network performs on the test set.

# %%
model_for_test = initial_model()

# We now add batch size to the mix of training parameters
# If you don't specify batch size below, all training data will be used for each learning step
batch_size = 512
epochs = 112

history_for_test = model_for_test.fit(x_train_all, r_train_all,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(history_for_test.epoch, np.array(history_for_test.history['accuracy']),'g-',
        label='Train accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Loss minimised by model')
plt.plot(history_for_test.epoch, np.array(history_for_test.history['loss']),'g-',
        label='Train loss')
plt.legend()

# %% [markdown]
# Now, we will save the whole model, i.e., both the network structure and the weights, because that makes it easier to analyse it in a separate notebook.

# %%
checkpoint_dir = "/content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/"
print("Models will be saved in ",checkpoint_dir)
# Out:
# Models will be saved in  /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/

# %%
#the file type for storing complete models is ".h5"
# feel free to change the path to whatever suits you best!
modelpath = checkpoint_dir+"final_model_nonau.h5"

print("Final model saved as ",modelpath)

# Save entire model to a HDF5 file
model_for_test.save(modelpath)
# Out:
# Final model saved as  /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/final_model.h5

# %% [markdown]
# Measuring the performance of the final model (on the test set)

# %%
# The code below should give the same results as that for the original model
[train_loss, train_accuracy] = model_for_test.evaluate(x_train_all, r_train_all, verbose=0)
print("Training set Accuracy:{:7.4f}".format(train_accuracy))
print("Training set Loss:{:7.6f}\n".format(train_loss))

[test_loss, test_accuracy] = model_for_test.evaluate(x_test, r_test, verbose=0)
print("Test set Accuracy:{:7.4f}".format(test_accuracy))
print("Test set Loss:{:7.6f}\n".format(test_loss))
# Out:
# Training set Accuracy: 0.9494
# Training set Loss:0.637571
#
# Test set Accuracy: 0.7411
# Test set Loss:1.381210

# %% [markdown]
# ###13. Final model training on full training data (with augmentation)
# Here, we re-train it on the full original training set (i.e., including the validation set) and use the number of EPOCHS that corresponds to our best validation score in the previous run (which is X), together with data augmentation. Once this re-training has been done, we analyse how our network performs on the test set.

# %%
batch_size = 512
epochs = 121

au_model_for_test = initial_model()
au_model_for_test.summary()
au_model_for_test.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# dummy file path here ... this is local on Colab!
filepath = 'au_model_for_test.h5'

datagen = ImageDataGenerator(
        # rotation_range=15.0,  # randomly rotate images in the range (degrees, 0 to 180) - note that rotation is more compute-intensive than shifting!!
        # width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        # height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        # vertical_flip=False,  # randomly flip images
        fill_mode = 'nearest', # what to do with 'new' pixels that occur as the result of a transformation
        # zoom_range = 0.2)  
        #shear_range = 15
)

# Compute quantities required for some augmentation functions
# (e.g., std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train_all, augment=True)

# Fit the model on the batches generated by datagen.flow().
au_history_for_test = au_model_for_test.fit(datagen.flow(x_train_all, r_train_all, batch_size=batch_size),
                                    epochs=epochs, steps_per_epoch=len(x_train_all) / batch_size)
                                    # validation_data=(x_val, r_val),
                                    # callbacks = callbacks)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_16 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_17 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_18 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_19 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 512)         590336
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_21 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# activation_22 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None,
# 97/97 [==============================] - 30s 309ms/step - loss: 1.4768 - accuracy: 0.7669
# Epoch 117/121
# 97/97 [==============================] - 30s 308ms/step - loss: 1.4847 - accuracy: 0.7645
# Epoch 118/121
# 97/97 [==============================] - 30s 308ms/step - loss: 1.4851 - accuracy: 0.7668
# Epoch 119/121
# 97/97 [==============================] - 30s 307ms/step - loss: 1.4857 - accuracy: 0.7648
# Epoch 120/121
# 97/97 [==============================] - 30s 308ms/step - loss: 1.5059 - accuracy: 0.7629
# Epoch 121/121
# 97/97 [==============================] - 30s 308ms/step - loss: 1.4952 - accuracy: 0.7655

# %%
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(au_history_for_test.epoch, np.array(au_history_for_test.history['accuracy']),'g-',
        label='Train accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Loss minimised by model')
plt.plot(au_history_for_test.epoch, np.array(au_history_for_test.history['loss']),'g-',
        label='Train loss')
plt.legend()

# %%
#the file type for storing complete models is ".h5"
# feel free to change the path to whatever suits you best!
modelpath = checkpoint_dir+"au_model_for_test.h5"

print("Final model saved as ",modelpath)

# Save entire model to a HDF5 file
au_model_for_test.save(modelpath)
# Out:
# Final model saved as  /content/gdrive/My Drive/Colab Notebooks/DL2021/GA2/au_model_for_test.h5

# %%
# The code below should give the same results as that for the original model
[train_loss, train_accuracy] = au_model_for_test.evaluate(x_train_all, r_train_all, verbose=0)
print("Training set Accuracy:{:7.4f}".format(train_accuracy))
print("Training set Loss:{:7.6f}\n".format(train_loss))

[test_loss, test_accuracy] = au_model_for_test.evaluate(x_test, r_test, verbose=0)
print("Test set Accuracy:{:7.4f}".format(test_accuracy))
print("Test set Loss:{:7.6f}\n".format(test_loss))
# Out:
# Training set Accuracy: 0.7412
# Training set Loss:1.576311
#
# Test set Accuracy: 0.6727
# Test set Loss:1.870633

# %% [markdown]
# ### 14. Further analysis on the test set (model without data augmentation)
#
# 1.   Misclassification

# %% [markdown]
# Now the predictions are carried out on test set and analysed for misclassified samples.

# %%
model_for_test = initial_model()
model_for_test.load_weights("/content/models/final_model_nonau.h5")

# %%
from sklearn.metrics import precision_recall_fscore_support as score

# Return Label from one hot encoding
def return_label(one_hot_lab):
    op = np.zeros(len(one_hot_lab))
    for i in range(len(one_hot_lab)):
        op[i] = np.argmax(one_hot_lab[i])
    return op.astype(int)

#Get the real label and not the on hot encoded label
r_test_label = return_label(r_test)

predictions = model_for_test.predict(x_test)
# final_model = keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks/Models/final_model/Checkpoints/final_model.h5')

# the predictions are class probabilities, 
# the argmax code line below finds the index of the class with the highest probability

test_predicted_class = np.argmax(predictions,axis=1)
misclassified = np.where(test_predicted_class!=r_test_label)[0]

# %%
# misclassified is a vector that contains the indices of all misclassified samples

print("There are ",misclassified.shape[0]," misclassified samples in the test set.")


precision, recall, f1, _ = score(r_test_label, test_predicted_class)
# Out:
# There are  2589  misclassified samples in the test set.

# %%
# the functions below have been borrowed/adapted from the notebook:
# https://www.tensorflow.org/tutorials/keras/classification

from PIL import Image

# this function plots the image with some annotations
def plot_image(predictions, true_label, img):
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("Predicted:{} {:2.0f}% \n(Real:{})".format(labels[predicted_label],
                                100*np.max(predictions),
                                labels[true_label]),
                                color=color)


# this function shows the predictions for this sample
def plot_value_array(predictions, true_label):
  plt.grid(False)
  tick_marks = np.arange(20)
  perc = np.linspace(0,1,11)
  plt.xticks(tick_marks, labels, rotation=90)
  plt.yticks(perc)
  thisplot = plt.bar(range(20), predictions, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions)
  plt.xlabel('Label')
  plt.ylabel('Prediction confidence')

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# probabilities for class that will be predicted
maxprob = np.max(predictions, axis=1)

# find 100 most certain misclassified samples
most_certain = np.argsort(maxprob[misclassified])
most_certain = misclassified[most_certain[-100:]]
np.random.shuffle(most_certain)

# now we visualise the samples we found

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 1
num_cols = 2
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*(num_cols+4), 2*(num_rows+2)))
for i in range(num_images):
  idx=most_certain[i]
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(predictions[idx], r_test_label[idx], np.reshape(x_test[idx],(32,32,3)))
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(predictions[idx], r_test_label[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Confusion Matrices

# %%
#Plot the confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(true_labels, predictions, 
                          classes =[], 
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    This code is adapted from 
    https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    cm = confusion_matrix(true_labels, predictions)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    
    num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
    if len(classes) == 0:
        num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
        classes = range(num_classes)
    plt.figure(figsize = (12,12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
#Plot the confusion matrix
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt


def plot_confusion_matrix(true_labels, predictions, 
                          classes =[], 
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    This code is adapted from 
    https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    cm = confusion_matrix(true_labels, predictions)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    
    num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
    if len(classes) == 0:
        num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
        classes = range(num_classes)
    plt.figure(figsize = (13,13))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
# An unnormalised confusion matrix shows the numbers of samples in each combination of true class/predicted class

plot_confusion_matrix(r_test_label, test_predicted_class)
# Out:
# Confusion matrix, without normalization

# %%
# A normalised confusion matrix shows for each true class, which fraction of its samples is predicted in each class
# since off-diagonal numbers are hopefully small, this is sometimes less informative

# for perfectly balances tasks, both should give the same information
# for (strongly) unbalanced tasks, they give complementary views

plot_confusion_matrix(r_test_label, test_predicted_class, normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ### 15. Further analysis on the test set (model with data augmentation)

# %%
model_for_test = initial_model()
model_for_test.load_weights("/content/models/au_model_for_test.h5")

# %% [markdown]
# 1. Misclassification

# %%
from sklearn.metrics import precision_recall_fscore_support as score

# Return Label from one hot encoding
def return_label(one_hot_lab):
    op = np.zeros(len(one_hot_lab))
    for i in range(len(one_hot_lab)):
        op[i] = np.argmax(one_hot_lab[i])
    return op.astype(int)

#Get the real label and not the on hot encoded label
r_test_label = return_label(r_test)

predictions = model_for_test.predict(x_test)
# final_model = keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks/Models/final_model/Checkpoints/final_model.h5')

# the predictions are class probabilities, 
# the argmax code line below finds the index of the class with the highest probability

test_predicted_class = np.argmax(predictions,axis=1)
misclassified = np.where(test_predicted_class!=r_test_label)[0]

# %%
# misclassified is a vector that contains the indices of all misclassified samples

print("There are ",misclassified.shape[0]," misclassified samples in the test set.")


precision, recall, f1, _ = score(r_test_label, test_predicted_class)
# Out:
# There are  3273  misclassified samples in the test set.

# %%
# the functions below have been borrowed/adapted from the notebook:
# https://www.tensorflow.org/tutorials/keras/classification

from PIL import Image

# this function plots the image with some annotations
def plot_image(predictions, true_label, img):
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("Predicted:{} {:2.0f}% \n(Real:{})".format(labels[predicted_label],
                                100*np.max(predictions),
                                labels[true_label]),
                                color=color)


# this function shows the predictions for this sample
def plot_value_array(predictions, true_label):
  plt.grid(False)
  tick_marks = np.arange(20)
  perc = np.linspace(0,1,11)
  plt.xticks(tick_marks, labels, rotation=90)
  plt.yticks(perc)
  thisplot = plt.bar(range(20), predictions, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions)
  plt.xlabel('Label')
  plt.ylabel('Prediction confidence')

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# probabilities for class that will be predicted
maxprob = np.max(predictions, axis=1)

# find 100 most certain misclassified samples
most_certain = np.argsort(maxprob[misclassified])
most_certain = misclassified[most_certain[-100:]]
np.random.shuffle(most_certain)

# now we visualise the samples we found

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 1
num_cols = 2
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*(num_cols+4), 2*(num_rows+2)))
for i in range(num_images):
  idx=most_certain[i]
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(predictions[idx], r_test_label[idx], np.reshape(x_test[idx],(32,32,3)))
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(predictions[idx], r_test_label[idx])
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Confusion Matrices

# %%
#Plot the confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(true_labels, predictions, 
                          classes =[], 
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    This code is adapted from 
    https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    cm = confusion_matrix(true_labels, predictions)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    
    num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
    if len(classes) == 0:
        num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
        classes = range(num_classes)
    plt.figure(figsize = (12,12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
#Plot the confusion matrix
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt


def plot_confusion_matrix(true_labels, predictions, 
                          classes =[], 
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    This code is adapted from 
    https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    cm = confusion_matrix(true_labels, predictions)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)
    
    num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
    if len(classes) == 0:
        num_classes = max(len(np.unique(true_labels)),len(np.unique(predictions)))
        classes = range(num_classes)
    plt.figure(figsize = (13,13))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
# An unnormalised confusion matrix shows the numbers of samples in each combination of true class/predicted class

plot_confusion_matrix(r_test_label, test_predicted_class)
# Out:
# Confusion matrix, without normalization

# %%
# A normalised confusion matrix shows for each true class, which fraction of its samples is predicted in each class
# since off-diagonal numbers are hopefully small, this is sometimes less informative

# for perfectly balances tasks, both should give the same information
# for (strongly) unbalanced tasks, they give complementary views

plot_confusion_matrix(r_test_label, test_predicted_class, normalize=True)
# Out:
# Normalized confusion matrix
